# %%
import rebound

# %%
# clear discards file
import os
discard_file_name = "discards.txt"

try:
    os.remove(discard_file_name)
except:
    pass

# %%
sim = rebound.Simulation()
sim.integrateor = "mercurius"
sim.units = ("yr", "AU", "Msun")

# %%
date = "2024-06-25 01:36"

# %%
sim.add("Sun", date=date, hash=0)
# Out:
# Searching NASA Horizons for 'Sun'...
# Found: Sun (10)

# %%
h = rebound.hash
print("Mass of the Sun = {}".format(sim.particles[h(0)].m))
# Out:
# Mass of the Sun = 0.9999999999950272

# %%
print("GM = {}".format(sim.G*sim.particles[h(0)].m))
# Out:
# GM = 39.47692642117669

# %%
sim.particles[h(0)].r = 0.0046524726

# %%
sim.add("Venus", hash=1)
sim.add("Earth", hash=2)
sim.add("Mars", hash=3)
sim.add("Jupiter", hash=4)
sim.add("Saturn", hash=5)
sim.add("Uranus", hash=6)
sim.add("Neptune", hash=7)
# Out:
# Searching NASA Horizons for 'Venus'...
# Found: Venus Barycenter (299) (chosen from query 'Venus')
# Searching NASA Horizons for 'Earth'...
# Found: Earth-Moon Barycenter (3) (chosen from query 'Earth')
# Searching NASA Horizons for 'Mars'...
# Found: Mars Barycenter (4) (chosen from query 'Mars')
# Searching NASA Horizons for 'Jupiter'...
# Found: Jupiter Barycenter (5) (chosen from query 'Jupiter')
# Searching NASA Horizons for 'Saturn'...
# Found: Saturn Barycenter (6) (chosen from query 'Saturn')
# Searching NASA Horizons for 'Uranus'...
# Found: Uranus Barycenter (7) (chosen from query 'Uranus')
# Searching NASA Horizons for 'Neptune'...
# Found: Neptune Barycenter (8) (chosen from query 'Neptune')

# %%
sim.particles[h(1)].r = 0.00004045
sim.particles[h(2)].r = 0.00004259
sim.particles[h(3)].r = 0.00002266
sim.particles[h(4)].r = 0.00046733
sim.particles[h(5)].r = 0.00038926
sim.particles[h(6)].r = 0.00016953
sim.particles[h(7)].r = 0.00016459

# %%
rebound.OrbitPlot(sim, unitlabel="[AU]")

# %%
sim.status()
# Out:
# ---------------------------------
# REBOUND version:     	4.4.1
# REBOUND built on:    	May  7 2024 19:45:53
# Number of particles: 	8
# Selected integrator: 	ias15
# Simulation time:     	0.0000000000000000e+00
# Current timestep:    	0.001000
# ---------------------------------
# <rebound.particle.Particle object at 0x249ff356ad0, m=0.9999999999950272 x=-0.006996076514134355 y=-0.0040250558070854675 z=0.00019863851999010358 vx=0.002251535520503117 vy=-0.002033708882019127 vz=-3.198278533676416e-05>
# <rebound.particle.Particle object at 0x249ff356350, m=2.447838287784771e-06 x=-0.2191547918333883 y=0.6825088358383847 z=0.021868990790396836 vx=-7.080682875581747 vy=-2.224477991578594 vz=0.3781371449816307>
# <rebound.particle.Particle object at 0x249ff356ad0, m=3.0404326489511185e-06 x=0.058039997136965074 y=-1.01840530168258 z=0.00025525187228331346 vx=6.171123450319233 vy=0.37630162527155236 vz=-8.743338838581358e-05>
# <rebound.particle.Particle object at 0x249ff356350, m=3.2271560828978514e-07 x=1.382021418570834 y=0.1462353704770263 z=-0.030722787241190794 vx=-0.3521266573003132 vy=5.5158813740679395 vz=0.12430067893772982>
# <rebound.particle.Particle object at 0x249ff356ad0, m=0.0009547919099366768 x=2.406242114146621 y=4.4036112618818315 z=-0.07210226139667628 vx=-2.4494811168192494 vy=1.45274633198291 vz=0.04877879965850054>
# <rebound.particle.Particle object at 0x249ff356350, m=0.0002858856700231729 x=9.263376759234507 y=-2.7963038526321786 z=-0.3201997150086051 vx=0.47533299416157987 vy=1.9466372929905578 vz=-0.052774799309414366>
# <rebound.particle.Particle object at 0x249ff356ad0, m=4.366249613200406e-05 x=11.710257643806965 y=15.68883954363977 z=-0.09344014348221087 vx=-1.161794340079309 vy=0.7923402739043611 vz=0.017993444927059437>
# <rebound.particle.Particle object at 0x249ff356350, m=5.151383772628957e-05 x=29.859400685500937 y=-1.2385566156671506 z=-0.6626345026956342 vx=0.039945098420725814 vy=1.1523834809621372 vz=-0.02465176876704687>
# ---------------------------------
# The following fields have non-default values:
# G:
# < 1.000000e+00
# ---
# > 3.947693e+01
# N:
# < 0
# ---
# > 8
# python_unit_l:
# < 0
# ---
# > 12937928
# python_unit_m:
# < 0
# ---
# > 2145773914
# python_unit_t:
# < 0
# ---
# > 1864791206
# rand_seed:
# < 134996
# ---
# > 722996
# particles:
# > (1024 bytes, values not printed)

# %%
N_pl = 8

# %%
import numpy as np

# %%
sim.add(a=1.8962438188689117, e=0.5378407335664053, inc=np.radians(41.35867805379716), Omega=np.radians(63.39172506103105), omega=np.radians(293.1079621092694), M=np.radians(306.24331451862315), hash=100)

# %%
sim.particles[h(100)].r = 2.8343E-8

# %%
rebound.OrbitPlot(sim, unitlabel="[AU]", xlim=[-5, 5], ylim=[-5,5], color=(N_pl-1)*["black"]+["red"])

# %%
x = sim.particles[h(100)].x
y = sim.particles[h(100)].y
z = sim.particles[h(100)].z
vx = sim.particles[h(100)].vx
vy = sim.particles[h(100)].vy
vz = sim.particles[h(100)].vz

# %%
N_tp = 20

# %%
from numpy.random import normal

# %%
# for i in range (1, N_tp):
#     sim.add(x = np.random.normal(x, 1E-4), y = np.random.normal(y, 1E-4), z = np.random.normal(z, 1E-4), vx = np.random.normal(vx, 1E-4), vy = np.random.normal(vy, 1E-4), vz = np.random.normal(vz, 1E-4), r=2.8343E-8, hash=100+i)

for i in range (1, N_tp):
    sim.add(a = np.random.normal(1.8962438188689117, 0.012859095718699871), e = np.random.normal(0.5378407335664053, 0.0017672322187828589), inc = np.radians(np.random.normal(41.35867805379716, 0.0060295872580306)), Omega = np.radians(np.random.normal(63.39172506103105, 0.0023695246243670455)), omega = np.radians(np.random.normal(293.1079621092694, 0.007573706747018616)), M = np.radians(np.random.normal(306.24331451862315, 0.7021402144495281)), r=2.8343E-8, hash=100+i)

# %%
rebound.OrbitPlot(sim, unitlabel="[AU]", xlim=[-5,5], ylim=[-5,5], color=(N_pl-1)*["black"]+N_tp*["red"])

# %%
sim.exit_max_distance = 1000
sim.collision = "direct"

# %%
def collision_discard_log(sim_pointer, collision, discard_file_name = discard_file_name):
    sim = sim_pointer.contents
    id_p1 = sim.particles[collision.p1].hash.value
    id_p2 = sim.particles[collision.p2].hash.value

    discard_file = open(discard-file_name, "a")

    if id_p1 > id_p2:
        print("Particle {0} collided with {1} at {2} yrs".format(id_p1, id_p2, sim.t))
        print("Particle {0} collided with {1} at {2} yrs".format(id_p1, id_p2, sim.t), file=discard.file)
        print("Removing particle {0}".format(id_p1))
        ToRemove = 1
    else:
        print("Particle {0} collided with {1} at {2} yrs".format(id_p2, id_p1, sim.t))
        print("Particle {0} collided with {1} at {2} yrs".format(id_p2, id_p1, sim.t), file=discard.file)
        print("Removing particle {0}".format(id_p2))
        ToRemove = 2

    discard_file.close()
    return ToRemove

# %%
sim.collision_resolve = collision_discard_log

# %%
sim.move_to_com()

# %%
tend = 50e6

# %%
tout = 1000

# %%
sim.dt = sim.particles[h(1)].P/25

# %%
archive = "archive_new.bin"
sim.save_to_file(archive, interval=tout, delete_file=True)

# %%
times = np.arange(0, tend, tout)
Nsteps = len(times)

# %%
for i in range(Nsteps):
    try:
        sim.integrate(times[i], exact_finish_time=0)
    except rebound.Escape as error:
        for j in range(sim.N):
            p = sim.particles[j]
            d2 = p.x**2 + p.y**2 + p.z**2
            if d2 > sim.exit_max_distance**2:
                index = j
        pid = sim.particles[index].hash.value
        print("Particle {0:2d} was too far from the Sun at {1:12.6e} yrs".format(pid, sim.t))
        discard_file = open(discard_file_name, "a")
        print("Particle {0:2d} was too far from the Sun at {1:12.6e} yrs".formta(pid, sim.t), file=discard_file)
        discard_file.close()
        sim.remove(index = index)
    print("Time {0:6.3f} Myr-- Fraction Done {1:5.4f} -- # of Clones {2}".format(sim.t/1e6, sim.t/tend, sim.N-N_pl))

    if sim.N <= N_pl:
        print("No more test particles, ending simulation")
        break
# Out:
# Time  0.000 Myr-- Fraction Done 0.0000 -- # of Clones 20
# Time  0.001 Myr-- Fraction Done 0.0000 -- # of Clones 20
# Time  0.002 Myr-- Fraction Done 0.0000 -- # of Clones 20
# Time  0.003 Myr-- Fraction Done 0.0001 -- # of Clones 20
# Time  0.004 Myr-- Fraction Done 0.0001 -- # of Clones 20
# Time  0.005 Myr-- Fraction Done 0.0001 -- # of Clones 20
# Time  0.006 Myr-- Fraction Done 0.0001 -- # of Clones 20
# Time  0.007 Myr-- Fraction Done 0.0001 -- # of Clones 20
# Time  0.008 Myr-- Fraction Done 0.0002 -- # of Clones 20
# Time  0.009 Myr-- Fraction Done 0.0002 -- # of Clones 20
# Time  0.010 Myr-- Fraction Done 0.0002 -- # of Clones 20
# Time  0.011 Myr-- Fraction Done 0.0002 -- # of Clones 20
# Time  0.012 Myr-- Fraction Done 0.0002 -- # of Clones 20
# Time  0.013 Myr-- Fraction Done 0.0003 -- # of Clones 20
# Time  0.014 Myr-- Fraction Done 0.0003 -- # of Clones 20
# Time  0.015 Myr-- Fraction Done 0.0003 -- # of Clones 20
# Time  0.016 Myr-- Fraction Done 0.0003 -- # of Clones 20
# Time  0.017 Myr-- Fraction Done 0.0003 -- # of Clones 20
# Time  0.018 Myr-- Fraction Done 0.0004 -- # of Clones 20
# Time  0.019 Myr-- Fraction Done 0.0004 -- # of Clones 20
# Time  0.020 Myr-- Fraction Done 0.0004 -- # of Clones 20
# Time  0.021 Myr-- Fraction Done 0.0004 -- # of Clones 20
# Time  0.022 Myr-- Fraction Done 0.0004 -- # of Clones 20
# Time  0.023 Myr-- Fraction Done 0.0005 -- # of Clones 20
# Time  0.024 Myr-- Fraction Done 0.0005 -- # of Clones 20
# Time  0.025 Myr-- Fraction Done 0.0005 -- # of Clones 20
# Time  0.026 Myr-- Fraction Done 0.0005 -- # of Clones 20
# Time  0.027 Myr-- Fraction Done 0.0005 -- # of Clones 20
# Time  0.028 Myr-- Fraction Done 0.0006 -- # of Clones 20
# Time  0.029 Myr-- Fraction Done 0.0006 -- # of Clones 20
# Time  0.030 Myr-- Fraction Done 0.0006 -- # of Clones 20
# Time  0.031 Myr-- Fraction Done 0.0006 -- # of Clones 20
# Time  0.032 Myr-- Fraction Done 0.0006 -- # of Clones 20
# Time  0.033 Myr-- Fraction Done 0.0007 -- # of Clones 20
# Time  0.034 Myr-- Fraction Done 0.0007 -- # of Clones 20
# Time  0.035 Myr-- Fraction Done 0.0007 -- # of Clones 20
# Time  0.036 Myr-- Fraction Done 0.0007 -- # of Clones 20
# Time  0.037 Myr-- Fraction Done 0.0007 -- # of Clones 20
# Time  0.038 Myr-- Fraction Done 0.0008 -- # of Clones 20
# Time  0.039 Myr-- Fraction Done 0.0008 -- # of Clones 20
# Time  0.040 Myr-- Fraction Done 0.0008 -- # of Clones 20
# Time  0.041 Myr-- Fraction Done 0.0008 -- # of Clones 20
# Time  0.042 Myr-- Fraction Done 0.0008 -- # of Clones 20
# Time  0.043 Myr-- Fraction Done 0.0009 -- # of Clones 20
# Time  0.044 Myr-- Fraction Done 0.0009 -- # of Clones 20
# Time  0.045 Myr-- Fraction Done 0.0009 -- # of Clones 20
# Time  0.046 Myr-- Fraction Done 0.0009 -- # of Clones 20
# Time  0.047 Myr-- Fraction Done 0.0009 -- # of Clones 20
# Time  0.048 Myr-- Fraction Done 0.0010 -- # of Clones 20
# Time  0.049 Myr-- Fraction Done 0.0010 -- # of Clones 20
# Time  0.050 Myr-- Fraction Done 0.0010 -- # of Clones 20
# Time  0.051 Myr-- Fraction Done 0.0010 -- # of Clones 20
# Time  0.052 Myr-- Fraction Done 0.0010 -- # of Clones 20
# Time  0.053 Myr-- Fraction Done 0.0011 -- # of Clones 20
# Time  0.054 Myr-- Fraction Done 0.0011 -- # of Clones 20
# Time  0.055 Myr-- Fraction Done 0.0011 -- # of Clones 20
# Time  0.056 Myr-- Fraction Done 0.0011 -- # of Clones 20
# Time  0.057 Myr-- Fraction Done 0.0011 -- # of Clones 20
# Time  0.058 Myr-- Fraction Done 0.0012 -- # of Clones 20
# Time  0.059 Myr-- Fraction Done 0.0012 -- # of Clones 20
# Time  0.060 Myr-- Fraction Done 0.0012 -- # of Clones 20
# Time  0.061 Myr-- Fraction Done 0.0012 -- # of Clones 20
# Time  0.062 Myr-- Fraction Done 0.0012 -- # of Clones 20
# Time  0.063 Myr-- Fraction Done 0.0013 -- # of Clones 20
# Time  0.064 Myr-- Fraction Done 0.0013 -- # of Clones 20
# Time  0.065 Myr-- Fraction Done 0.0013 -- # of Clones 20
# Time  0.066 Myr-- Fraction Done 0.0013 -- # of Clones 20
# Time  0.067 Myr-- Fraction Done 0.0013 -- # of Clones 20
# Time  0.068 Myr-- Fraction Done 0.0014 -- # of Clones 20
# Time  0.069 Myr-- Fraction Done 0.0014 -- # of Clones 20
# Time  0.070 Myr-- Fraction Done 0.0014 -- # of Clones 20
# Time  0.071 Myr-- Fraction Done 0.0014 -- # of Clones 20
# Time  0.072 Myr-- Fraction Done 0.0014 -- # of Clones 20
# Time  0.073 Myr-- Fraction Done 0.0015 -- # of Clones 20
# Time  0.074 Myr-- Fraction Done 0.0015 -- # of Clones 20
# Time  0.075 Myr-- Fraction Done 0.0015 -- # of Clones 20
# Time  0.076 Myr-- Fraction Done 0.0015 -- # of Clones 20
# Time  0.077 Myr-- Fraction Done 0.0015 -- # of Clones 20
# Time  0.078 Myr-- Fraction Done 0.0016 -- # of Clones 20
# Time  0.079 Myr-- Fraction Done 0.0016 -- # of Clones 20
# Time  0.080 Myr-- Fraction Done 0.0016 -- # of Clones 20
# Time  0.081 Myr-- Fraction Done 0.0016 -- # of Clones 20
# Time  0.082 Myr-- Fraction Done 0.0016 -- # of Clones 20
# Time  0.083 Myr-- Fraction Done 0.0017 -- # of Clones 20
# Time  0.084 Myr-- Fraction Done 0.0017 -- # of Clones 20
# Time  0.085 Myr-- Fraction Done 0.0017 -- # of Clones 20
# Time  0.086 Myr-- Fraction Done 0.0017 -- # of Clones 20
# Time  0.087 Myr-- Fraction Done 0.0017 -- # of Clones 20
# Time  0.088 Myr-- Fraction Done 0.0018 -- # of Clones 20
# Time  0.089 Myr-- Fraction Done 0.0018 -- # of Clones 20
# Time  0.090 Myr-- Fraction Done 0.0018 -- # of Clones 20
# Time  0.091 Myr-- Fraction Done 0.0018 -- # of Clones 20
# Time  0.092 Myr-- Fraction Done 0.0018 -- # of Clones 20
# Time  0.093 Myr-- Fraction Done 0.0019 -- # of Clones 20
# Time  0.094 Myr-- Fraction Done 0.0019 -- # of Clones 20
# Time  0.095 Myr-- Fraction Done 0.0019 -- # of Clones 20
# Time  0.096 Myr-- Fraction Done 0.0019 -- # of Clones 20
# Time  0.097 Myr-- Fraction Done 0.0019 -- # of Clones 20
# Time  0.098 Myr-- Fraction Done 0.0020 -- # of Clones 20
# Time  0.099 Myr-- Fraction Done 0.0020 -- # of Clones 20
# Time  0.100 Myr-- Fraction Done 0.0020 -- # of Clones 20
# Time  0.101 Myr-- Fraction Done 0.0020 -- # of Clones 20
# Time  0.102 Myr-- Fraction Done 0.0020 -- # of Clones 20
# Time  0.103 Myr-- Fraction Done 0.0021 -- # of Clones 20
# Time  0.104 Myr-- Fraction Done 0.0021 -- # of Clones 20
# Time  0.105 Myr-- Fraction Done 0.0021 -- # of Clones 20
# Time  0.106 Myr-- Fraction Done 0.0021 -- # of Clones 20
# Time  0.107 Myr-- Fraction Done 0.0021 -- # of Clones 20
# Time  0.108 Myr-- Fraction Done 0.0022 -- # of Clones 20
# Time  0.109 Myr-- Fraction Done 0.0022 -- # of Clones 20
# Time  0.110 Myr-- Fraction Done 0.0022 -- # of Clones 20
# Time  0.111 Myr-- Fraction Done 0.0022 -- # of Clones 20
# Time  0.112 Myr-- Fraction Done 0.0022 -- # of Clones 20
# Time  0.113 Myr-- Fraction Done 0.0023 -- # of Clones 20
# Time  0.114 Myr-- Fraction Done 0.0023 -- # of Clones 20
# Time  0.115 Myr-- Fraction Done 0.0023 -- # of Clones 20
# Time  0.116 Myr-- Fraction Done 0.0023 -- # of Clones 20
# Time  0.117 Myr-- Fraction Done 0.0023 -- # of Clones 20
# Time  0.118 Myr-- Fraction Done 0.0024 -- # of Clones 20
# Time  0.119 Myr-- Fraction Done 0.0024 -- # of Clones 20
# Time  0.120 Myr-- Fraction Done 0.0024 -- # of Clones 20
# Time  0.121 Myr-- Fraction Done 0.0024 -- # of Clones 20
# Time  0.122 Myr-- Fraction Done 0.0024 -- # of Clones 20
# Time  0.123 Myr-- Fraction Done 0.0025 -- # of Clones 20
# Time  0.124 Myr-- Fraction Done 0.0025 -- # of Clones 20
# Time  0.125 Myr-- Fraction Done 0.0025 -- # of Clones 20
# Time  0.126 Myr-- Fraction Done 0.0025 -- # of Clones 20
# Time  0.127 Myr-- Fraction Done 0.0025 -- # of Clones 20
# Time  0.128 Myr-- Fraction Done 0.0026 -- # of Clones 20
# Time  0.129 Myr-- Fraction Done 0.0026 -- # of Clones 20
# Time  0.130 Myr-- Fraction Done 0.0026 -- # of Clones 20
# Time  0.131 Myr-- Fraction Done 0.0026 -- # of Clones 20
# Time  0.132 Myr-- Fraction Done 0.0026 -- # of Clones 20
# Time  0.133 Myr-- Fraction Done 0.0027 -- # of Clones 20
# Time  0.134 Myr-- Fraction Done 0.0027 -- # of Clones 20
# Time  0.135 Myr-- Fraction Done 0.0027 -- # of Clones 20
# Time  0.136 Myr-- Fraction Done 0.0027 -- # of Clones 20
# Time  0.137 Myr-- Fraction Done 0.0027 -- # of Clones 20
# Time  0.138 Myr-- Fraction Done 0.0028 -- # of Clones 20
# Time  0.139 Myr-- Fraction Done 0.0028 -- # of Clones 20
# Time  0.140 Myr-- Fraction Done 0.0028 -- # of Clones 20
# Time  0.141 Myr-- Fraction Done 0.0028 -- # of Clones 20
# Time  0.142 Myr-- Fraction Done 0.0028 -- # of Clones 20
# Time  0.143 Myr-- Fraction Done 0.0029 -- # of Clones 20
# Time  0.144 Myr-- Fraction Done 0.0029 -- # of Clones 20
# Time  0.145 Myr-- Fraction Done 0.0029 -- # of Clones 20
# Time  0.146 Myr-- Fraction Done 0.0029 -- # of Clones 20
# Time  0.147 Myr-- Fraction Done 0.0029 -- # of Clones 20
# Time  0.148 Myr-- Fraction Done 0.0030 -- # of Clones 20
# Time  0.149 Myr-- Fraction Done 0.0030 -- # of Clones 20
# Time  0.150 Myr-- Fraction Done 0.0030 -- # of Clones 20
# Time  0.151 Myr-- Fraction Done 0.0030 -- # of Clones 20
# Time  0.152 Myr-- Fraction Done 0.0030 -- # of Clones 20
# Time  0.153 Myr-- Fraction Done 0.0031 -- # of Clones 20
# Time  0.154 Myr-- Fraction Done 0.0031 -- # of Clones 20
# Time  0.155 Myr-- Fraction Done 0.0031 -- # of Clones 20
# Time  0.156 Myr-- Fraction Done 0.0031 -- # of Clones 20
# Time  0.157 Myr-- Fraction Done 0.0031 -- # of Clones 20
# Time  0.158 Myr-- Fraction Done 0.0032 -- # of Clones 20
# Time  0.159 Myr-- Fraction Done 0.0032 -- # of Clones 20
# Time  0.160 Myr-- Fraction Done 0.0032 -- # of Clones 20
# Time  0.161 Myr-- Fraction Done 0.0032 -- # of Clones 20
# Time  0.162 Myr-- Fraction Done 0.0032 -- # of Clones 20
# Time  0.163 Myr-- Fraction Done 0.0033 -- # of Clones 20
# Time  0.164 Myr-- Fraction Done 0.0033 -- # of Clones 20
# Time  0.165 Myr-- Fraction Done 0.0033 -- # of Clones 20
# Time  0.166 Myr-- Fraction Done 0.0033 -- # of Clones 20
# Time  0.167 Myr-- Fraction Done 0.0033 -- # of Clones 20
# Time  0.168 Myr-- Fraction Done 0.0034 -- # of Clones 20
# Time  0.169 Myr-- Fraction Done 0.0034 -- # of Clones 20
# Time  0.170 Myr-- Fraction Done 0.0034 -- # of Clones 20
# Time  0.171 Myr-- Fraction Done 0.0034 -- # of Clones 20
# Time  0.172 Myr-- Fraction Done 0.0034 -- # of Clones 20
# Time  0.173 Myr-- Fraction Done 0.0035 -- # of Clones 20
# Time  0.174 Myr-- Fraction Done 0.0035 -- # of Clones 20
# Time  0.175 Myr-- Fraction Done 0.0035 -- # of Clones 20
# Time  0.176 Myr-- Fraction Done 0.0035 -- # of Clones 20
# Time  0.177 Myr-- Fraction Done 0.0035 -- # of Clones 20
# Time  0.178 Myr-- Fraction Done 0.0036 -- # of Clones 20
# Time  0.179 Myr-- Fraction Done 0.0036 -- # of Clones 20
# Time  0.180 Myr-- Fraction Done 0.0036 -- # of Clones 20
# Time  0.181 Myr-- Fraction Done 0.0036 -- # of Clones 20
# Time  0.182 Myr-- Fraction Done 0.0036 -- # of Clones 20
# Time  0.183 Myr-- Fraction Done 0.0037 -- # of Clones 20
# Time  0.184 Myr-- Fraction Done 0.0037 -- # of Clones 20
# Time  0.185 Myr-- Fraction Done 0.0037 -- # of Clones 20
# Time  0.186 Myr-- Fraction Done 0.0037 -- # of Clones 20
# Time  0.187 Myr-- Fraction Done 0.0037 -- # of Clones 20
# Time  0.188 Myr-- Fraction Done 0.0038 -- # of Clones 20
# Time  0.189 Myr-- Fraction Done 0.0038 -- # of Clones 20
# Time  0.190 Myr-- Fraction Done 0.0038 -- # of Clones 20
# Time  0.191 Myr-- Fraction Done 0.0038 -- # of Clones 20
# Time  0.192 Myr-- Fraction Done 0.0038 -- # of Clones 20
# Time  0.193 Myr-- Fraction Done 0.0039 -- # of Clones 20
# Time  0.194 Myr-- Fraction Done 0.0039 -- # of Clones 20
# Time  0.195 Myr-- Fraction Done 0.0039 -- # of Clones 20
# Time  0.196 Myr-- Fraction Done 0.0039 -- # of Clones 20
# Time  0.197 Myr-- Fraction Done 0.0039 -- # of Clones 20
# Time  0.198 Myr-- Fraction Done 0.0040 -- # of Clones 20
# Time  0.199 Myr-- Fraction Done 0.0040 -- # of Clones 20
# Time  0.200 Myr-- Fraction Done 0.0040 -- # of Clones 20
# Time  0.201 Myr-- Fraction Done 0.0040 -- # of Clones 20
# Time  0.202 Myr-- Fraction Done 0.0040 -- # of Clones 20
# Time  0.203 Myr-- Fraction Done 0.0041 -- # of Clones 20
# Time  0.204 Myr-- Fraction Done 0.0041 -- # of Clones 20
# Time  0.205 Myr-- Fraction Done 0.0041 -- # of Clones 20
# Time  0.206 Myr-- Fraction Done 0.0041 -- # of Clones 20
# Time  0.207 Myr-- Fraction Done 0.0041 -- # of Clones 20
# Time  0.208 Myr-- Fraction Done 0.0042 -- # of Clones 20
# Time  0.209 Myr-- Fraction Done 0.0042 -- # of Clones 20
# Time  0.210 Myr-- Fraction Done 0.0042 -- # of Clones 20
# Time  0.211 Myr-- Fraction Done 0.0042 -- # of Clones 20
# Time  0.212 Myr-- Fraction Done 0.0042 -- # of Clones 20
# Time  0.213 Myr-- Fraction Done 0.0043 -- # of Clones 20
# Time  0.214 Myr-- Fraction Done 0.0043 -- # of Clones 20
# Time  0.215 Myr-- Fraction Done 0.0043 -- # of Clones 20
# Time  0.216 Myr-- Fraction Done 0.0043 -- # of Clones 20
# Time  0.217 Myr-- Fraction Done 0.0043 -- # of Clones 20
# Time  0.218 Myr-- Fraction Done 0.0044 -- # of Clones 20
# Time  0.219 Myr-- Fraction Done 0.0044 -- # of Clones 20
# Time  0.220 Myr-- Fraction Done 0.0044 -- # of Clones 20
# Time  0.221 Myr-- Fraction Done 0.0044 -- # of Clones 20
# Time  0.222 Myr-- Fraction Done 0.0044 -- # of Clones 20
# Time  0.223 Myr-- Fraction Done 0.0045 -- # of Clones 20
# Time  0.224 Myr-- Fraction Done 0.0045 -- # of Clones 20
# Time  0.225 Myr-- Fraction Done 0.0045 -- # of Clones 20
# Time  0.226 Myr-- Fraction Done 0.0045 -- # of Clones 20
# Time  0.227 Myr-- Fraction Done 0.0045 -- # of Clones 20
# Time  0.228 Myr-- Fraction Done 0.0046 -- # of Clones 20
# Time  0.229 Myr-- Fraction Done 0.0046 -- # of Clones 20
# Time  0.230 Myr-- Fraction Done 0.0046 -- # of Clones 20
# Time  0.231 Myr-- Fraction Done 0.0046 -- # of Clones 20
# Time  0.232 Myr-- Fraction Done 0.0046 -- # of Clones 20
# Time  0.233 Myr-- Fraction Done 0.0047 -- # of Clones 20
# Time  0.234 Myr-- Fraction Done 0.0047 -- # of Clones 20
# Time  0.235 Myr-- Fraction Done 0.0047 -- # of Clones 20
# Time  0.236 Myr-- Fraction Done 0.0047 -- # of Clones 20
# Time  0.237 Myr-- Fraction Done 0.0047 -- # of Clones 20
# Time  0.238 Myr-- Fraction Done 0.0048 -- # of Clones 20
# Time  0.239 Myr-- Fraction Done 0.0048 -- # of Clones 20
# Time  0.240 Myr-- Fraction Done 0.0048 -- # of Clones 20
# Time  0.241 Myr-- Fraction Done 0.0048 -- # of Clones 20
# Time  0.242 Myr-- Fraction Done 0.0048 -- # of Clones 20
# Time  0.243 Myr-- Fraction Done 0.0049 -- # of Clones 20
# Time  0.244 Myr-- Fraction Done 0.0049 -- # of Clones 20
# Time  0.245 Myr-- Fraction Done 0.0049 -- # of Clones 20
# Time  0.246 Myr-- Fraction Done 0.0049 -- # of Clones 20
# Time  0.247 Myr-- Fraction Done 0.0049 -- # of Clones 20
# Time  0.248 Myr-- Fraction Done 0.0050 -- # of Clones 20
# Time  0.249 Myr-- Fraction Done 0.0050 -- # of Clones 20
# Time  0.250 Myr-- Fraction Done 0.0050 -- # of Clones 20
# Time  0.251 Myr-- Fraction Done 0.0050 -- # of Clones 20
# Time  0.252 Myr-- Fraction Done 0.0050 -- # of Clones 20
# Time  0.253 Myr-- Fraction Done 0.0051 -- # of Clones 20
# Time  0.254 Myr-- Fraction Done 0.0051 -- # of Clones 20
# Time  0.255 Myr-- Fraction Done 0.0051 -- # of Clones 20
# Time  0.256 Myr-- Fraction Done 0.0051 -- # of Clones 20
# Time  0.257 Myr-- Fraction Done 0.0051 -- # of Clones 20
# Time  0.258 Myr-- Fraction Done 0.0052 -- # of Clones 20
# Time  0.259 Myr-- Fraction Done 0.0052 -- # of Clones 20
# Time  0.260 Myr-- Fraction Done 0.0052 -- # of Clones 20
# Time  0.261 Myr-- Fraction Done 0.0052 -- # of Clones 20
# Time  0.262 Myr-- Fraction Done 0.0052 -- # of Clones 20
# Time  0.263 Myr-- Fraction Done 0.0053 -- # of Clones 20
# Time  0.264 Myr-- Fraction Done 0.0053 -- # of Clones 20
# Time  0.265 Myr-- Fraction Done 0.0053 -- # of Clones 20
# Time  0.266 Myr-- Fraction Done 0.0053 -- # of Clones 20
# Time  0.267 Myr-- Fraction Done 0.0053 -- # of Clones 20
# Time  0.268 Myr-- Fraction Done 0.0054 -- # of Clones 20
# Time  0.269 Myr-- Fraction Done 0.0054 -- # of Clones 20
# Time  0.270 Myr-- Fraction Done 0.0054 -- # of Clones 20
# Time  0.271 Myr-- Fraction Done 0.0054 -- # of Clones 20
# Time  0.272 Myr-- Fraction Done 0.0054 -- # of Clones 20
# Time  0.273 Myr-- Fraction Done 0.0055 -- # of Clones 20
# Time  0.274 Myr-- Fraction Done 0.0055 -- # of Clones 20
# Time  0.275 Myr-- Fraction Done 0.0055 -- # of Clones 20
# Time  0.276 Myr-- Fraction Done 0.0055 -- # of Clones 20
# Time  0.277 Myr-- Fraction Done 0.0055 -- # of Clones 20
# Time  0.278 Myr-- Fraction Done 0.0056 -- # of Clones 20
# Time  0.279 Myr-- Fraction Done 0.0056 -- # of Clones 20
# Time  0.280 Myr-- Fraction Done 0.0056 -- # of Clones 20
# Time  0.281 Myr-- Fraction Done 0.0056 -- # of Clones 20
# Time  0.282 Myr-- Fraction Done 0.0056 -- # of Clones 20
# Time  0.283 Myr-- Fraction Done 0.0057 -- # of Clones 20
# Time  0.284 Myr-- Fraction Done 0.0057 -- # of Clones 20
# Time  0.285 Myr-- Fraction Done 0.0057 -- # of Clones 20
# Time  0.286 Myr-- Fraction Done 0.0057 -- # of Clones 20
# Time  0.287 Myr-- Fraction Done 0.0057 -- # of Clones 20
# Time  0.288 Myr-- Fraction Done 0.0058 -- # of Clones 20
# Time  0.289 Myr-- Fraction Done 0.0058 -- # of Clones 20
# Time  0.290 Myr-- Fraction Done 0.0058 -- # of Clones 20
# Time  0.291 Myr-- Fraction Done 0.0058 -- # of Clones 20
# Time  0.292 Myr-- Fraction Done 0.0058 -- # of Clones 20
# Time  0.293 Myr-- Fraction Done 0.0059 -- # of Clones 20
# Time  0.294 Myr-- Fraction Done 0.0059 -- # of Clones 20
# Time  0.295 Myr-- Fraction Done 0.0059 -- # of Clones 20
# Time  0.296 Myr-- Fraction Done 0.0059 -- # of Clones 20
# Time  0.297 Myr-- Fraction Done 0.0059 -- # of Clones 20
# Time  0.298 Myr-- Fraction Done 0.0060 -- # of Clones 20
# Time  0.299 Myr-- Fraction Done 0.0060 -- # of Clones 20
# Time  0.300 Myr-- Fraction Done 0.0060 -- # of Clones 20
# Time  0.301 Myr-- Fraction Done 0.0060 -- # of Clones 20
# Time  0.302 Myr-- Fraction Done 0.0060 -- # of Clones 20
# Time  0.303 Myr-- Fraction Done 0.0061 -- # of Clones 20
# Time  0.304 Myr-- Fraction Done 0.0061 -- # of Clones 20
# Time  0.305 Myr-- Fraction Done 0.0061 -- # of Clones 20
# Time  0.306 Myr-- Fraction Done 0.0061 -- # of Clones 20
# Time  0.307 Myr-- Fraction Done 0.0061 -- # of Clones 20
# Time  0.308 Myr-- Fraction Done 0.0062 -- # of Clones 20
# Time  0.309 Myr-- Fraction Done 0.0062 -- # of Clones 20
# Time  0.310 Myr-- Fraction Done 0.0062 -- # of Clones 20
# Time  0.311 Myr-- Fraction Done 0.0062 -- # of Clones 20
# Time  0.312 Myr-- Fraction Done 0.0062 -- # of Clones 20
# Time  0.313 Myr-- Fraction Done 0.0063 -- # of Clones 20
# Time  0.314 Myr-- Fraction Done 0.0063 -- # of Clones 20
# Time  0.315 Myr-- Fraction Done 0.0063 -- # of Clones 20
# Time  0.316 Myr-- Fraction Done 0.0063 -- # of Clones 20
# Time  0.317 Myr-- Fraction Done 0.0063 -- # of Clones 20
# Time  0.318 Myr-- Fraction Done 0.0064 -- # of Clones 20
# Time  0.319 Myr-- Fraction Done 0.0064 -- # of Clones 20
# Time  0.320 Myr-- Fraction Done 0.0064 -- # of Clones 20
# Time  0.321 Myr-- Fraction Done 0.0064 -- # of Clones 20
# Time  0.322 Myr-- Fraction Done 0.0064 -- # of Clones 20
# Time  0.323 Myr-- Fraction Done 0.0065 -- # of Clones 20
# Time  0.324 Myr-- Fraction Done 0.0065 -- # of Clones 20
# Time  0.325 Myr-- Fraction Done 0.0065 -- # of Clones 20
# Time  0.326 Myr-- Fraction Done 0.0065 -- # of Clones 20
# Time  0.327 Myr-- Fraction Done 0.0065 -- # of Clones 20
# Time  0.328 Myr-- Fraction Done 0.0066 -- # of Clones 20
# Time  0.329 Myr-- Fraction Done 0.0066 -- # of Clones 20
# Time  0.330 Myr-- Fraction Done 0.0066 -- # of Clones 20
# Time  0.331 Myr-- Fraction Done 0.0066 -- # of Clones 20
# Time  0.332 Myr-- Fraction Done 0.0066 -- # of Clones 20
# Time  0.333 Myr-- Fraction Done 0.0067 -- # of Clones 20
# Time  0.334 Myr-- Fraction Done 0.0067 -- # of Clones 20
# Time  0.335 Myr-- Fraction Done 0.0067 -- # of Clones 20
# Time  0.336 Myr-- Fraction Done 0.0067 -- # of Clones 20
# Time  0.337 Myr-- Fraction Done 0.0067 -- # of Clones 20
# Time  0.338 Myr-- Fraction Done 0.0068 -- # of Clones 20
# Time  0.339 Myr-- Fraction Done 0.0068 -- # of Clones 20
# Time  0.340 Myr-- Fraction Done 0.0068 -- # of Clones 20
# Time  0.341 Myr-- Fraction Done 0.0068 -- # of Clones 20
# Time  0.342 Myr-- Fraction Done 0.0068 -- # of Clones 20
# Time  0.343 Myr-- Fraction Done 0.0069 -- # of Clones 20
# Time  0.344 Myr-- Fraction Done 0.0069 -- # of Clones 20
# Time  0.345 Myr-- Fraction Done 0.0069 -- # of Clones 20
# Time  0.346 Myr-- Fraction Done 0.0069 -- # of Clones 20
# Time  0.347 Myr-- Fraction Done 0.0069 -- # of Clones 20
# Time  0.348 Myr-- Fraction Done 0.0070 -- # of Clones 20
# Time  0.349 Myr-- Fraction Done 0.0070 -- # of Clones 20
# Time  0.350 Myr-- Fraction Done 0.0070 -- # of Clones 20
# Time  0.351 Myr-- Fraction Done 0.0070 -- # of Clones 20
# Time  0.352 Myr-- Fraction Done 0.0070 -- # of Clones 20
# Time  0.353 Myr-- Fraction Done 0.0071 -- # of Clones 20
# Time  0.354 Myr-- Fraction Done 0.0071 -- # of Clones 20
# Time  0.355 Myr-- Fraction Done 0.0071 -- # of Clones 20
# Time  0.356 Myr-- Fraction Done 0.0071 -- # of Clones 20
# Time  0.357 Myr-- Fraction Done 0.0071 -- # of Clones 20
# Time  0.358 Myr-- Fraction Done 0.0072 -- # of Clones 20
# Time  0.359 Myr-- Fraction Done 0.0072 -- # of Clones 20
# Time  0.360 Myr-- Fraction Done 0.0072 -- # of Clones 20
# Time  0.361 Myr-- Fraction Done 0.0072 -- # of Clones 20
# Time  0.362 Myr-- Fraction Done 0.0072 -- # of Clones 20
# Time  0.363 Myr-- Fraction Done 0.0073 -- # of Clones 20
# Time  0.364 Myr-- Fraction Done 0.0073 -- # of Clones 20
# Time  0.365 Myr-- Fraction Done 0.0073 -- # of Clones 20
# Time  0.366 Myr-- Fraction Done 0.0073 -- # of Clones 20
# Time  0.367 Myr-- Fraction Done 0.0073 -- # of Clones 20
# Time  0.368 Myr-- Fraction Done 0.0074 -- # of Clones 20
# Time  0.369 Myr-- Fraction Done 0.0074 -- # of Clones 20
# Time  0.370 Myr-- Fraction Done 0.0074 -- # of Clones 20
# Time  0.371 Myr-- Fraction Done 0.0074 -- # of Clones 20
# Time  0.372 Myr-- Fraction Done 0.0074 -- # of Clones 20
# Time  0.373 Myr-- Fraction Done 0.0075 -- # of Clones 20
# Time  0.374 Myr-- Fraction Done 0.0075 -- # of Clones 20
# Time  0.375 Myr-- Fraction Done 0.0075 -- # of Clones 20
# Time  0.376 Myr-- Fraction Done 0.0075 -- # of Clones 20
# Time  0.377 Myr-- Fraction Done 0.0075 -- # of Clones 20
# Time  0.378 Myr-- Fraction Done 0.0076 -- # of Clones 20
# Time  0.379 Myr-- Fraction Done 0.0076 -- # of Clones 20
# Time  0.380 Myr-- Fraction Done 0.0076 -- # of Clones 20
# Time  0.381 Myr-- Fraction Done 0.0076 -- # of Clones 20
# Time  0.382 Myr-- Fraction Done 0.0076 -- # of Clones 20
# Time  0.383 Myr-- Fraction Done 0.0077 -- # of Clones 20
# Time  0.384 Myr-- Fraction Done 0.0077 -- # of Clones 20
# Time  0.385 Myr-- Fraction Done 0.0077 -- # of Clones 20
# Time  0.386 Myr-- Fraction Done 0.0077 -- # of Clones 20
# Time  0.387 Myr-- Fraction Done 0.0077 -- # of Clones 20
# Time  0.388 Myr-- Fraction Done 0.0078 -- # of Clones 20
# Time  0.389 Myr-- Fraction Done 0.0078 -- # of Clones 20
# Time  0.390 Myr-- Fraction Done 0.0078 -- # of Clones 20
# Time  0.391 Myr-- Fraction Done 0.0078 -- # of Clones 20
# Time  0.392 Myr-- Fraction Done 0.0078 -- # of Clones 20
# Time  0.393 Myr-- Fraction Done 0.0079 -- # of Clones 20
# Time  0.394 Myr-- Fraction Done 0.0079 -- # of Clones 20
# Time  0.395 Myr-- Fraction Done 0.0079 -- # of Clones 20
# Time  0.396 Myr-- Fraction Done 0.0079 -- # of Clones 20
# Time  0.397 Myr-- Fraction Done 0.0079 -- # of Clones 20
# Time  0.398 Myr-- Fraction Done 0.0080 -- # of Clones 20
# Time  0.399 Myr-- Fraction Done 0.0080 -- # of Clones 20
# Time  0.400 Myr-- Fraction Done 0.0080 -- # of Clones 20
# Time  0.401 Myr-- Fraction Done 0.0080 -- # of Clones 20
# Time  0.402 Myr-- Fraction Done 0.0080 -- # of Clones 20
# Time  0.403 Myr-- Fraction Done 0.0081 -- # of Clones 20
# Time  0.404 Myr-- Fraction Done 0.0081 -- # of Clones 20
# Time  0.405 Myr-- Fraction Done 0.0081 -- # of Clones 20
# Time  0.406 Myr-- Fraction Done 0.0081 -- # of Clones 20
# Time  0.407 Myr-- Fraction Done 0.0081 -- # of Clones 20
# Time  0.408 Myr-- Fraction Done 0.0082 -- # of Clones 20
# Time  0.409 Myr-- Fraction Done 0.0082 -- # of Clones 20
# Time  0.410 Myr-- Fraction Done 0.0082 -- # of Clones 20
# Time  0.411 Myr-- Fraction Done 0.0082 -- # of Clones 20
# Time  0.412 Myr-- Fraction Done 0.0082 -- # of Clones 20
# Time  0.413 Myr-- Fraction Done 0.0083 -- # of Clones 20
# Time  0.414 Myr-- Fraction Done 0.0083 -- # of Clones 20
# Time  0.415 Myr-- Fraction Done 0.0083 -- # of Clones 20
# Time  0.416 Myr-- Fraction Done 0.0083 -- # of Clones 20
# Time  0.417 Myr-- Fraction Done 0.0083 -- # of Clones 20
# Time  0.418 Myr-- Fraction Done 0.0084 -- # of Clones 20
# Time  0.419 Myr-- Fraction Done 0.0084 -- # of Clones 20
# Time  0.420 Myr-- Fraction Done 0.0084 -- # of Clones 20
# Time  0.421 Myr-- Fraction Done 0.0084 -- # of Clones 20
# Time  0.422 Myr-- Fraction Done 0.0084 -- # of Clones 20
# Time  0.423 Myr-- Fraction Done 0.0085 -- # of Clones 20
# Time  0.424 Myr-- Fraction Done 0.0085 -- # of Clones 20
# Time  0.425 Myr-- Fraction Done 0.0085 -- # of Clones 20
# Time  0.426 Myr-- Fraction Done 0.0085 -- # of Clones 20
# Time  0.427 Myr-- Fraction Done 0.0085 -- # of Clones 20
# Time  0.428 Myr-- Fraction Done 0.0086 -- # of Clones 20
# Time  0.429 Myr-- Fraction Done 0.0086 -- # of Clones 20
# Time  0.430 Myr-- Fraction Done 0.0086 -- # of Clones 20
# Time  0.431 Myr-- Fraction Done 0.0086 -- # of Clones 20
# Time  0.432 Myr-- Fraction Done 0.0086 -- # of Clones 20
# Time  0.433 Myr-- Fraction Done 0.0087 -- # of Clones 20
# Time  0.434 Myr-- Fraction Done 0.0087 -- # of Clones 20
# Time  0.435 Myr-- Fraction Done 0.0087 -- # of Clones 20
# Time  0.436 Myr-- Fraction Done 0.0087 -- # of Clones 20
# Time  0.437 Myr-- Fraction Done 0.0087 -- # of Clones 20
# Time  0.438 Myr-- Fraction Done 0.0088 -- # of Clones 20
# Time  0.439 Myr-- Fraction Done 0.0088 -- # of Clones 20
# Time  0.440 Myr-- Fraction Done 0.0088 -- # of Clones 20
# Time  0.441 Myr-- Fraction Done 0.0088 -- # of Clones 20
# Time  0.442 Myr-- Fraction Done 0.0088 -- # of Clones 20
# Time  0.443 Myr-- Fraction Done 0.0089 -- # of Clones 20
# Time  0.444 Myr-- Fraction Done 0.0089 -- # of Clones 20
# Time  0.445 Myr-- Fraction Done 0.0089 -- # of Clones 20
# Time  0.446 Myr-- Fraction Done 0.0089 -- # of Clones 20
# Time  0.447 Myr-- Fraction Done 0.0089 -- # of Clones 20
# Time  0.448 Myr-- Fraction Done 0.0090 -- # of Clones 20
# Time  0.449 Myr-- Fraction Done 0.0090 -- # of Clones 20
# Time  0.450 Myr-- Fraction Done 0.0090 -- # of Clones 20
# Time  0.451 Myr-- Fraction Done 0.0090 -- # of Clones 20
# Time  0.452 Myr-- Fraction Done 0.0090 -- # of Clones 20
# Time  0.453 Myr-- Fraction Done 0.0091 -- # of Clones 20
# Time  0.454 Myr-- Fraction Done 0.0091 -- # of Clones 20
# Time  0.455 Myr-- Fraction Done 0.0091 -- # of Clones 20
# Time  0.456 Myr-- Fraction Done 0.0091 -- # of Clones 20
# Time  0.457 Myr-- Fraction Done 0.0091 -- # of Clones 20
# Time  0.458 Myr-- Fraction Done 0.0092 -- # of Clones 20
# Time  0.459 Myr-- Fraction Done 0.0092 -- # of Clones 20
# Time  0.460 Myr-- Fraction Done 0.0092 -- # of Clones 20
# Time  0.461 Myr-- Fraction Done 0.0092 -- # of Clones 20
# Time  0.462 Myr-- Fraction Done 0.0092 -- # of Clones 20
# Time  0.463 Myr-- Fraction Done 0.0093 -- # of Clones 20
# Time  0.464 Myr-- Fraction Done 0.0093 -- # of Clones 20
# Time  0.465 Myr-- Fraction Done 0.0093 -- # of Clones 20
# Time  0.466 Myr-- Fraction Done 0.0093 -- # of Clones 20
# Time  0.467 Myr-- Fraction Done 0.0093 -- # of Clones 20
# Time  0.468 Myr-- Fraction Done 0.0094 -- # of Clones 20
# Time  0.469 Myr-- Fraction Done 0.0094 -- # of Clones 20
# Time  0.470 Myr-- Fraction Done 0.0094 -- # of Clones 20
# Time  0.471 Myr-- Fraction Done 0.0094 -- # of Clones 20
# Time  0.472 Myr-- Fraction Done 0.0094 -- # of Clones 20
# Time  0.473 Myr-- Fraction Done 0.0095 -- # of Clones 20
# Time  0.474 Myr-- Fraction Done 0.0095 -- # of Clones 20
# Time  0.475 Myr-- Fraction Done 0.0095 -- # of Clones 20
# Time  0.476 Myr-- Fraction Done 0.0095 -- # of Clones 20
# Time  0.477 Myr-- Fraction Done 0.0095 -- # of Clones 20
# Time  0.478 Myr-- Fraction Done 0.0096 -- # of Clones 20
# Time  0.479 Myr-- Fraction Done 0.0096 -- # of Clones 20
# Time  0.480 Myr-- Fraction Done 0.0096 -- # of Clones 20
# Time  0.481 Myr-- Fraction Done 0.0096 -- # of Clones 20
# Time  0.482 Myr-- Fraction Done 0.0096 -- # of Clones 20
# Time  0.483 Myr-- Fraction Done 0.0097 -- # of Clones 20
# Time  0.484 Myr-- Fraction Done 0.0097 -- # of Clones 20
# Time  0.485 Myr-- Fraction Done 0.0097 -- # of Clones 20
# Time  0.486 Myr-- Fraction Done 0.0097 -- # of Clones 20
# Time  0.487 Myr-- Fraction Done 0.0097 -- # of Clones 20
# Time  0.488 Myr-- Fraction Done 0.0098 -- # of Clones 20
# Time  0.489 Myr-- Fraction Done 0.0098 -- # of Clones 20
# Time  0.490 Myr-- Fraction Done 0.0098 -- # of Clones 20
# Time  0.491 Myr-- Fraction Done 0.0098 -- # of Clones 20
# Time  0.492 Myr-- Fraction Done 0.0098 -- # of Clones 20
# Time  0.493 Myr-- Fraction Done 0.0099 -- # of Clones 20
# Time  0.494 Myr-- Fraction Done 0.0099 -- # of Clones 20
# Time  0.495 Myr-- Fraction Done 0.0099 -- # of Clones 20
# Time  0.496 Myr-- Fraction Done 0.0099 -- # of Clones 20
# Time  0.497 Myr-- Fraction Done 0.0099 -- # of Clones 20
# Time  0.498 Myr-- Fraction Done 0.0100 -- # of Clones 20
# Time  0.499 Myr-- Fraction Done 0.0100 -- # of Clones 20
# Time  0.500 Myr-- Fraction Done 0.0100 -- # of Clones 20
# Time  0.501 Myr-- Fraction Done 0.0100 -- # of Clones 20
# Time  0.502 Myr-- Fraction Done 0.0100 -- # of Clones 20
# Time  0.503 Myr-- Fraction Done 0.0101 -- # of Clones 20
# Time  0.504 Myr-- Fraction Done 0.0101 -- # of Clones 20
# Time  0.505 Myr-- Fraction Done 0.0101 -- # of Clones 20
# Time  0.506 Myr-- Fraction Done 0.0101 -- # of Clones 20
# Time  0.507 Myr-- Fraction Done 0.0101 -- # of Clones 20
# Time  0.508 Myr-- Fraction Done 0.0102 -- # of Clones 20
# Time  0.509 Myr-- Fraction Done 0.0102 -- # of Clones 20
# Time  0.510 Myr-- Fraction Done 0.0102 -- # of Clones 20
# Time  0.511 Myr-- Fraction Done 0.0102 -- # of Clones 20
# Time  0.512 Myr-- Fraction Done 0.0102 -- # of Clones 20
# Time  0.513 Myr-- Fraction Done 0.0103 -- # of Clones 20
# Time  0.514 Myr-- Fraction Done 0.0103 -- # of Clones 20
# Time  0.515 Myr-- Fraction Done 0.0103 -- # of Clones 20
# Time  0.516 Myr-- Fraction Done 0.0103 -- # of Clones 20
# Time  0.517 Myr-- Fraction Done 0.0103 -- # of Clones 20
# Time  0.518 Myr-- Fraction Done 0.0104 -- # of Clones 20
# Time  0.519 Myr-- Fraction Done 0.0104 -- # of Clones 20
# Time  0.520 Myr-- Fraction Done 0.0104 -- # of Clones 20
# Time  0.521 Myr-- Fraction Done 0.0104 -- # of Clones 20
# Time  0.522 Myr-- Fraction Done 0.0104 -- # of Clones 20
# Time  0.523 Myr-- Fraction Done 0.0105 -- # of Clones 20
# Time  0.524 Myr-- Fraction Done 0.0105 -- # of Clones 20
# Time  0.525 Myr-- Fraction Done 0.0105 -- # of Clones 20
# Time  0.526 Myr-- Fraction Done 0.0105 -- # of Clones 20
# Time  0.527 Myr-- Fraction Done 0.0105 -- # of Clones 20
# Time  0.528 Myr-- Fraction Done 0.0106 -- # of Clones 20
# Time  0.529 Myr-- Fraction Done 0.0106 -- # of Clones 20
# Time  0.530 Myr-- Fraction Done 0.0106 -- # of Clones 20
# Time  0.531 Myr-- Fraction Done 0.0106 -- # of Clones 20
# Time  0.532 Myr-- Fraction Done 0.0106 -- # of Clones 20
# Time  0.533 Myr-- Fraction Done 0.0107 -- # of Clones 20
# Time  0.534 Myr-- Fraction Done 0.0107 -- # of Clones 20
# Time  0.535 Myr-- Fraction Done 0.0107 -- # of Clones 20
# Time  0.536 Myr-- Fraction Done 0.0107 -- # of Clones 20
# Time  0.537 Myr-- Fraction Done 0.0107 -- # of Clones 20
# Time  0.538 Myr-- Fraction Done 0.0108 -- # of Clones 20
# Time  0.539 Myr-- Fraction Done 0.0108 -- # of Clones 20
# Time  0.540 Myr-- Fraction Done 0.0108 -- # of Clones 20
# Time  0.541 Myr-- Fraction Done 0.0108 -- # of Clones 20
# Time  0.542 Myr-- Fraction Done 0.0108 -- # of Clones 20
# Time  0.543 Myr-- Fraction Done 0.0109 -- # of Clones 20
# Time  0.544 Myr-- Fraction Done 0.0109 -- # of Clones 20
# Time  0.545 Myr-- Fraction Done 0.0109 -- # of Clones 20
# Time  0.546 Myr-- Fraction Done 0.0109 -- # of Clones 20
# Time  0.547 Myr-- Fraction Done 0.0109 -- # of Clones 20
# Time  0.548 Myr-- Fraction Done 0.0110 -- # of Clones 20
# Time  0.549 Myr-- Fraction Done 0.0110 -- # of Clones 20
# Time  0.550 Myr-- Fraction Done 0.0110 -- # of Clones 20
# Time  0.551 Myr-- Fraction Done 0.0110 -- # of Clones 20
# Time  0.552 Myr-- Fraction Done 0.0110 -- # of Clones 20
# Time  0.553 Myr-- Fraction Done 0.0111 -- # of Clones 20
# Time  0.554 Myr-- Fraction Done 0.0111 -- # of Clones 20
# Time  0.555 Myr-- Fraction Done 0.0111 -- # of Clones 20
# Time  0.556 Myr-- Fraction Done 0.0111 -- # of Clones 20
# Time  0.557 Myr-- Fraction Done 0.0111 -- # of Clones 20
# Time  0.558 Myr-- Fraction Done 0.0112 -- # of Clones 20
# Time  0.559 Myr-- Fraction Done 0.0112 -- # of Clones 20
# Time  0.560 Myr-- Fraction Done 0.0112 -- # of Clones 20
# Time  0.561 Myr-- Fraction Done 0.0112 -- # of Clones 20
# Time  0.562 Myr-- Fraction Done 0.0112 -- # of Clones 20
# Time  0.563 Myr-- Fraction Done 0.0113 -- # of Clones 20
# Time  0.564 Myr-- Fraction Done 0.0113 -- # of Clones 20
# Time  0.565 Myr-- Fraction Done 0.0113 -- # of Clones 20
# Time  0.566 Myr-- Fraction Done 0.0113 -- # of Clones 20
# Time  0.567 Myr-- Fraction Done 0.0113 -- # of Clones 20
# Time  0.568 Myr-- Fraction Done 0.0114 -- # of Clones 20
# Time  0.569 Myr-- Fraction Done 0.0114 -- # of Clones 20
# Time  0.570 Myr-- Fraction Done 0.0114 -- # of Clones 20
# Time  0.571 Myr-- Fraction Done 0.0114 -- # of Clones 20
# Time  0.572 Myr-- Fraction Done 0.0114 -- # of Clones 20
# Time  0.573 Myr-- Fraction Done 0.0115 -- # of Clones 20
# Time  0.574 Myr-- Fraction Done 0.0115 -- # of Clones 20
# Time  0.575 Myr-- Fraction Done 0.0115 -- # of Clones 20
# Time  0.576 Myr-- Fraction Done 0.0115 -- # of Clones 20
# Time  0.577 Myr-- Fraction Done 0.0115 -- # of Clones 20
# Time  0.578 Myr-- Fraction Done 0.0116 -- # of Clones 20
# Time  0.579 Myr-- Fraction Done 0.0116 -- # of Clones 20
# Time  0.580 Myr-- Fraction Done 0.0116 -- # of Clones 20
# Time  0.581 Myr-- Fraction Done 0.0116 -- # of Clones 20
# Time  0.582 Myr-- Fraction Done 0.0116 -- # of Clones 20
# Time  0.583 Myr-- Fraction Done 0.0117 -- # of Clones 20
# Time  0.584 Myr-- Fraction Done 0.0117 -- # of Clones 20
# Time  0.585 Myr-- Fraction Done 0.0117 -- # of Clones 20
# Time  0.586 Myr-- Fraction Done 0.0117 -- # of Clones 20
# Time  0.587 Myr-- Fraction Done 0.0117 -- # of Clones 20
# Time  0.588 Myr-- Fraction Done 0.0118 -- # of Clones 20
# Time  0.589 Myr-- Fraction Done 0.0118 -- # of Clones 20
# Time  0.590 Myr-- Fraction Done 0.0118 -- # of Clones 20
# Time  0.591 Myr-- Fraction Done 0.0118 -- # of Clones 20
# Time  0.592 Myr-- Fraction Done 0.0118 -- # of Clones 20
# Time  0.593 Myr-- Fraction Done 0.0119 -- # of Clones 20
# Time  0.594 Myr-- Fraction Done 0.0119 -- # of Clones 20
# Time  0.595 Myr-- Fraction Done 0.0119 -- # of Clones 20
# Time  0.596 Myr-- Fraction Done 0.0119 -- # of Clones 20
# Time  0.597 Myr-- Fraction Done 0.0119 -- # of Clones 20
# Time  0.598 Myr-- Fraction Done 0.0120 -- # of Clones 20
# Time  0.599 Myr-- Fraction Done 0.0120 -- # of Clones 20
# Time  0.600 Myr-- Fraction Done 0.0120 -- # of Clones 20
# Time  0.601 Myr-- Fraction Done 0.0120 -- # of Clones 20
# Time  0.602 Myr-- Fraction Done 0.0120 -- # of Clones 20
# Time  0.603 Myr-- Fraction Done 0.0121 -- # of Clones 20
# Time  0.604 Myr-- Fraction Done 0.0121 -- # of Clones 20
# Time  0.605 Myr-- Fraction Done 0.0121 -- # of Clones 20
# Time  0.606 Myr-- Fraction Done 0.0121 -- # of Clones 20
# Time  0.607 Myr-- Fraction Done 0.0121 -- # of Clones 20
# Time  0.608 Myr-- Fraction Done 0.0122 -- # of Clones 20
# Time  0.609 Myr-- Fraction Done 0.0122 -- # of Clones 20
# Time  0.610 Myr-- Fraction Done 0.0122 -- # of Clones 20
# Time  0.611 Myr-- Fraction Done 0.0122 -- # of Clones 20
# Time  0.612 Myr-- Fraction Done 0.0122 -- # of Clones 20
# Time  0.613 Myr-- Fraction Done 0.0123 -- # of Clones 20
# Time  0.614 Myr-- Fraction Done 0.0123 -- # of Clones 20
# Time  0.615 Myr-- Fraction Done 0.0123 -- # of Clones 20
# Time  0.616 Myr-- Fraction Done 0.0123 -- # of Clones 20
# Time  0.617 Myr-- Fraction Done 0.0123 -- # of Clones 20
# Time  0.618 Myr-- Fraction Done 0.0124 -- # of Clones 20
# Time  0.619 Myr-- Fraction Done 0.0124 -- # of Clones 20
# Time  0.620 Myr-- Fraction Done 0.0124 -- # of Clones 20
# Time  0.621 Myr-- Fraction Done 0.0124 -- # of Clones 20
# Time  0.622 Myr-- Fraction Done 0.0124 -- # of Clones 20
# Time  0.623 Myr-- Fraction Done 0.0125 -- # of Clones 20
# Time  0.624 Myr-- Fraction Done 0.0125 -- # of Clones 20
# Time  0.625 Myr-- Fraction Done 0.0125 -- # of Clones 20
# Time  0.626 Myr-- Fraction Done 0.0125 -- # of Clones 20
# Time  0.627 Myr-- Fraction Done 0.0125 -- # of Clones 20
# Time  0.628 Myr-- Fraction Done 0.0126 -- # of Clones 20
# Time  0.629 Myr-- Fraction Done 0.0126 -- # of Clones 20
# Time  0.630 Myr-- Fraction Done 0.0126 -- # of Clones 20
# Time  0.631 Myr-- Fraction Done 0.0126 -- # of Clones 20
# Time  0.632 Myr-- Fraction Done 0.0126 -- # of Clones 20
# Time  0.633 Myr-- Fraction Done 0.0127 -- # of Clones 20
# Time  0.634 Myr-- Fraction Done 0.0127 -- # of Clones 20
# Time  0.635 Myr-- Fraction Done 0.0127 -- # of Clones 20
# Time  0.636 Myr-- Fraction Done 0.0127 -- # of Clones 20
# Time  0.637 Myr-- Fraction Done 0.0127 -- # of Clones 20
# Time  0.638 Myr-- Fraction Done 0.0128 -- # of Clones 20
# Time  0.639 Myr-- Fraction Done 0.0128 -- # of Clones 20
# Time  0.640 Myr-- Fraction Done 0.0128 -- # of Clones 20
# Time  0.641 Myr-- Fraction Done 0.0128 -- # of Clones 20
# Time  0.642 Myr-- Fraction Done 0.0128 -- # of Clones 20
# Time  0.643 Myr-- Fraction Done 0.0129 -- # of Clones 20
# Time  0.644 Myr-- Fraction Done 0.0129 -- # of Clones 20
# Time  0.645 Myr-- Fraction Done 0.0129 -- # of Clones 20
# Time  0.646 Myr-- Fraction Done 0.0129 -- # of Clones 20
# Time  0.647 Myr-- Fraction Done 0.0129 -- # of Clones 20
# Time  0.648 Myr-- Fraction Done 0.0130 -- # of Clones 20
# Time  0.649 Myr-- Fraction Done 0.0130 -- # of Clones 20
# Time  0.650 Myr-- Fraction Done 0.0130 -- # of Clones 20
# Time  0.651 Myr-- Fraction Done 0.0130 -- # of Clones 20
# Time  0.652 Myr-- Fraction Done 0.0130 -- # of Clones 20
# Time  0.653 Myr-- Fraction Done 0.0131 -- # of Clones 20
# Time  0.654 Myr-- Fraction Done 0.0131 -- # of Clones 20
# Time  0.655 Myr-- Fraction Done 0.0131 -- # of Clones 20
# Time  0.656 Myr-- Fraction Done 0.0131 -- # of Clones 20
# Time  0.657 Myr-- Fraction Done 0.0131 -- # of Clones 20
# Time  0.658 Myr-- Fraction Done 0.0132 -- # of Clones 20
# Time  0.659 Myr-- Fraction Done 0.0132 -- # of Clones 20
# Time  0.660 Myr-- Fraction Done 0.0132 -- # of Clones 20
# Time  0.661 Myr-- Fraction Done 0.0132 -- # of Clones 20
# Time  0.662 Myr-- Fraction Done 0.0132 -- # of Clones 20
# Time  0.663 Myr-- Fraction Done 0.0133 -- # of Clones 20
# Time  0.664 Myr-- Fraction Done 0.0133 -- # of Clones 20
# Time  0.665 Myr-- Fraction Done 0.0133 -- # of Clones 20
# Time  0.666 Myr-- Fraction Done 0.0133 -- # of Clones 20
# Time  0.667 Myr-- Fraction Done 0.0133 -- # of Clones 20
# Time  0.668 Myr-- Fraction Done 0.0134 -- # of Clones 20
# Time  0.669 Myr-- Fraction Done 0.0134 -- # of Clones 20
# Time  0.670 Myr-- Fraction Done 0.0134 -- # of Clones 20
# Time  0.671 Myr-- Fraction Done 0.0134 -- # of Clones 20
# Time  0.672 Myr-- Fraction Done 0.0134 -- # of Clones 20
# Time  0.673 Myr-- Fraction Done 0.0135 -- # of Clones 20
# Time  0.674 Myr-- Fraction Done 0.0135 -- # of Clones 20
# Time  0.675 Myr-- Fraction Done 0.0135 -- # of Clones 20
# Time  0.676 Myr-- Fraction Done 0.0135 -- # of Clones 20
# Time  0.677 Myr-- Fraction Done 0.0135 -- # of Clones 20
# Time  0.678 Myr-- Fraction Done 0.0136 -- # of Clones 20
# Time  0.679 Myr-- Fraction Done 0.0136 -- # of Clones 20
# Time  0.680 Myr-- Fraction Done 0.0136 -- # of Clones 20
# Time  0.681 Myr-- Fraction Done 0.0136 -- # of Clones 20
# Time  0.682 Myr-- Fraction Done 0.0136 -- # of Clones 20
# Time  0.683 Myr-- Fraction Done 0.0137 -- # of Clones 20
# Time  0.684 Myr-- Fraction Done 0.0137 -- # of Clones 20
# Time  0.685 Myr-- Fraction Done 0.0137 -- # of Clones 20
# Time  0.686 Myr-- Fraction Done 0.0137 -- # of Clones 20
# Time  0.687 Myr-- Fraction Done 0.0137 -- # of Clones 20
# Time  0.688 Myr-- Fraction Done 0.0138 -- # of Clones 20
# Time  0.689 Myr-- Fraction Done 0.0138 -- # of Clones 20
# Time  0.690 Myr-- Fraction Done 0.0138 -- # of Clones 20
# Time  0.691 Myr-- Fraction Done 0.0138 -- # of Clones 20
# Time  0.692 Myr-- Fraction Done 0.0138 -- # of Clones 20
# Time  0.693 Myr-- Fraction Done 0.0139 -- # of Clones 20
# Time  0.694 Myr-- Fraction Done 0.0139 -- # of Clones 20
# Time  0.695 Myr-- Fraction Done 0.0139 -- # of Clones 20
# Time  0.696 Myr-- Fraction Done 0.0139 -- # of Clones 20
# Time  0.697 Myr-- Fraction Done 0.0139 -- # of Clones 20
# Time  0.698 Myr-- Fraction Done 0.0140 -- # of Clones 20
# Time  0.699 Myr-- Fraction Done 0.0140 -- # of Clones 20
# Time  0.700 Myr-- Fraction Done 0.0140 -- # of Clones 20
# Time  0.701 Myr-- Fraction Done 0.0140 -- # of Clones 20
# Time  0.702 Myr-- Fraction Done 0.0140 -- # of Clones 20
# Time  0.703 Myr-- Fraction Done 0.0141 -- # of Clones 20
# Time  0.704 Myr-- Fraction Done 0.0141 -- # of Clones 20
# Time  0.705 Myr-- Fraction Done 0.0141 -- # of Clones 20
# Time  0.706 Myr-- Fraction Done 0.0141 -- # of Clones 20
# Time  0.707 Myr-- Fraction Done 0.0141 -- # of Clones 20
# Time  0.708 Myr-- Fraction Done 0.0142 -- # of Clones 20
# Time  0.709 Myr-- Fraction Done 0.0142 -- # of Clones 20
# Time  0.710 Myr-- Fraction Done 0.0142 -- # of Clones 20
# Time  0.711 Myr-- Fraction Done 0.0142 -- # of Clones 20
# Time  0.712 Myr-- Fraction Done 0.0142 -- # of Clones 20
# Time  0.713 Myr-- Fraction Done 0.0143 -- # of Clones 20
# Time  0.714 Myr-- Fraction Done 0.0143 -- # of Clones 20
# Time  0.715 Myr-- Fraction Done 0.0143 -- # of Clones 20
# Time  0.716 Myr-- Fraction Done 0.0143 -- # of Clones 20
# Time  0.717 Myr-- Fraction Done 0.0143 -- # of Clones 20
# Time  0.718 Myr-- Fraction Done 0.0144 -- # of Clones 20
# Time  0.719 Myr-- Fraction Done 0.0144 -- # of Clones 20
# Time  0.720 Myr-- Fraction Done 0.0144 -- # of Clones 20
# Time  0.721 Myr-- Fraction Done 0.0144 -- # of Clones 20
# Time  0.722 Myr-- Fraction Done 0.0144 -- # of Clones 20
# Time  0.723 Myr-- Fraction Done 0.0145 -- # of Clones 20
# Time  0.724 Myr-- Fraction Done 0.0145 -- # of Clones 20
# Time  0.725 Myr-- Fraction Done 0.0145 -- # of Clones 20
# Time  0.726 Myr-- Fraction Done 0.0145 -- # of Clones 20
# Time  0.727 Myr-- Fraction Done 0.0145 -- # of Clones 20
# Time  0.728 Myr-- Fraction Done 0.0146 -- # of Clones 20
# Time  0.729 Myr-- Fraction Done 0.0146 -- # of Clones 20
# Time  0.730 Myr-- Fraction Done 0.0146 -- # of Clones 20
# Time  0.731 Myr-- Fraction Done 0.0146 -- # of Clones 20
# Time  0.732 Myr-- Fraction Done 0.0146 -- # of Clones 20
# Time  0.733 Myr-- Fraction Done 0.0147 -- # of Clones 20
# Time  0.734 Myr-- Fraction Done 0.0147 -- # of Clones 20
# Time  0.735 Myr-- Fraction Done 0.0147 -- # of Clones 20
# Time  0.736 Myr-- Fraction Done 0.0147 -- # of Clones 20
# Time  0.737 Myr-- Fraction Done 0.0147 -- # of Clones 20
# Time  0.738 Myr-- Fraction Done 0.0148 -- # of Clones 20
# Time  0.739 Myr-- Fraction Done 0.0148 -- # of Clones 20
# Time  0.740 Myr-- Fraction Done 0.0148 -- # of Clones 20
# Time  0.741 Myr-- Fraction Done 0.0148 -- # of Clones 20
# Time  0.742 Myr-- Fraction Done 0.0148 -- # of Clones 20
# Time  0.743 Myr-- Fraction Done 0.0149 -- # of Clones 20
# Time  0.744 Myr-- Fraction Done 0.0149 -- # of Clones 20
# Time  0.745 Myr-- Fraction Done 0.0149 -- # of Clones 20
# Time  0.746 Myr-- Fraction Done 0.0149 -- # of Clones 20
# Time  0.747 Myr-- Fraction Done 0.0149 -- # of Clones 20
# Time  0.748 Myr-- Fraction Done 0.0150 -- # of Clones 20
# Time  0.749 Myr-- Fraction Done 0.0150 -- # of Clones 20
# Time  0.750 Myr-- Fraction Done 0.0150 -- # of Clones 20
# Time  0.751 Myr-- Fraction Done 0.0150 -- # of Clones 20
# Time  0.752 Myr-- Fraction Done 0.0150 -- # of Clones 20
# Time  0.753 Myr-- Fraction Done 0.0151 -- # of Clones 20
# Time  0.754 Myr-- Fraction Done 0.0151 -- # of Clones 20
# Time  0.755 Myr-- Fraction Done 0.0151 -- # of Clones 20
# Time  0.756 Myr-- Fraction Done 0.0151 -- # of Clones 20
# Time  0.757 Myr-- Fraction Done 0.0151 -- # of Clones 20
# Time  0.758 Myr-- Fraction Done 0.0152 -- # of Clones 20
# Time  0.759 Myr-- Fraction Done 0.0152 -- # of Clones 20
# Time  0.760 Myr-- Fraction Done 0.0152 -- # of Clones 20
# Time  0.761 Myr-- Fraction Done 0.0152 -- # of Clones 20
# Time  0.762 Myr-- Fraction Done 0.0152 -- # of Clones 20
# Time  0.763 Myr-- Fraction Done 0.0153 -- # of Clones 20
# Time  0.764 Myr-- Fraction Done 0.0153 -- # of Clones 20
# Time  0.765 Myr-- Fraction Done 0.0153 -- # of Clones 20
# Time  0.766 Myr-- Fraction Done 0.0153 -- # of Clones 20
# Time  0.767 Myr-- Fraction Done 0.0153 -- # of Clones 20
# Time  0.768 Myr-- Fraction Done 0.0154 -- # of Clones 20
# Time  0.769 Myr-- Fraction Done 0.0154 -- # of Clones 20
# Time  0.770 Myr-- Fraction Done 0.0154 -- # of Clones 20
# Time  0.771 Myr-- Fraction Done 0.0154 -- # of Clones 20
# Time  0.772 Myr-- Fraction Done 0.0154 -- # of Clones 20
# Time  0.773 Myr-- Fraction Done 0.0155 -- # of Clones 20
# Time  0.774 Myr-- Fraction Done 0.0155 -- # of Clones 20
# Time  0.775 Myr-- Fraction Done 0.0155 -- # of Clones 20
# Time  0.776 Myr-- Fraction Done 0.0155 -- # of Clones 20
# Time  0.777 Myr-- Fraction Done 0.0155 -- # of Clones 20
# Time  0.778 Myr-- Fraction Done 0.0156 -- # of Clones 20
# Time  0.779 Myr-- Fraction Done 0.0156 -- # of Clones 20
# Time  0.780 Myr-- Fraction Done 0.0156 -- # of Clones 20
# Time  0.781 Myr-- Fraction Done 0.0156 -- # of Clones 20
# Time  0.782 Myr-- Fraction Done 0.0156 -- # of Clones 20
# Time  0.783 Myr-- Fraction Done 0.0157 -- # of Clones 20
# Time  0.784 Myr-- Fraction Done 0.0157 -- # of Clones 20
# Time  0.785 Myr-- Fraction Done 0.0157 -- # of Clones 20
# Time  0.786 Myr-- Fraction Done 0.0157 -- # of Clones 20
# Time  0.787 Myr-- Fraction Done 0.0157 -- # of Clones 20
# Time  0.788 Myr-- Fraction Done 0.0158 -- # of Clones 20
# Time  0.789 Myr-- Fraction Done 0.0158 -- # of Clones 20
# Time  0.790 Myr-- Fraction Done 0.0158 -- # of Clones 20
# Time  0.791 Myr-- Fraction Done 0.0158 -- # of Clones 20
# Time  0.792 Myr-- Fraction Done 0.0158 -- # of Clones 20
# Time  0.793 Myr-- Fraction Done 0.0159 -- # of Clones 20
# Time  0.794 Myr-- Fraction Done 0.0159 -- # of Clones 20
# Time  0.795 Myr-- Fraction Done 0.0159 -- # of Clones 20
# Time  0.796 Myr-- Fraction Done 0.0159 -- # of Clones 20
# Time  0.797 Myr-- Fraction Done 0.0159 -- # of Clones 20
# Time  0.798 Myr-- Fraction Done 0.0160 -- # of Clones 20
# Time  0.799 Myr-- Fraction Done 0.0160 -- # of Clones 20
# Time  0.800 Myr-- Fraction Done 0.0160 -- # of Clones 20
# Time  0.801 Myr-- Fraction Done 0.0160 -- # of Clones 20
# Time  0.802 Myr-- Fraction Done 0.0160 -- # of Clones 20
# Time  0.803 Myr-- Fraction Done 0.0161 -- # of Clones 20
# Time  0.804 Myr-- Fraction Done 0.0161 -- # of Clones 20
# Time  0.805 Myr-- Fraction Done 0.0161 -- # of Clones 20
# Time  0.806 Myr-- Fraction Done 0.0161 -- # of Clones 20
# Time  0.807 Myr-- Fraction Done 0.0161 -- # of Clones 20
# Time  0.808 Myr-- Fraction Done 0.0162 -- # of Clones 20
# Time  0.809 Myr-- Fraction Done 0.0162 -- # of Clones 20
# Time  0.810 Myr-- Fraction Done 0.0162 -- # of Clones 20
# Time  0.811 Myr-- Fraction Done 0.0162 -- # of Clones 20
# Time  0.812 Myr-- Fraction Done 0.0162 -- # of Clones 20
# Time  0.813 Myr-- Fraction Done 0.0163 -- # of Clones 20
# Time  0.814 Myr-- Fraction Done 0.0163 -- # of Clones 20
# Time  0.815 Myr-- Fraction Done 0.0163 -- # of Clones 20
# Time  0.816 Myr-- Fraction Done 0.0163 -- # of Clones 20
# Time  0.817 Myr-- Fraction Done 0.0163 -- # of Clones 20
# Time  0.818 Myr-- Fraction Done 0.0164 -- # of Clones 20
# Time  0.819 Myr-- Fraction Done 0.0164 -- # of Clones 20
# Time  0.820 Myr-- Fraction Done 0.0164 -- # of Clones 20
# Time  0.821 Myr-- Fraction Done 0.0164 -- # of Clones 20
# Time  0.822 Myr-- Fraction Done 0.0164 -- # of Clones 20
# Time  0.823 Myr-- Fraction Done 0.0165 -- # of Clones 20
# Time  0.824 Myr-- Fraction Done 0.0165 -- # of Clones 20
# Time  0.825 Myr-- Fraction Done 0.0165 -- # of Clones 20
# Time  0.826 Myr-- Fraction Done 0.0165 -- # of Clones 20
# Time  0.827 Myr-- Fraction Done 0.0165 -- # of Clones 20
# Time  0.828 Myr-- Fraction Done 0.0166 -- # of Clones 20
# Time  0.829 Myr-- Fraction Done 0.0166 -- # of Clones 20
# Time  0.830 Myr-- Fraction Done 0.0166 -- # of Clones 20
# Time  0.831 Myr-- Fraction Done 0.0166 -- # of Clones 20
# Time  0.832 Myr-- Fraction Done 0.0166 -- # of Clones 20
# Time  0.833 Myr-- Fraction Done 0.0167 -- # of Clones 20
# Time  0.834 Myr-- Fraction Done 0.0167 -- # of Clones 20
# Time  0.835 Myr-- Fraction Done 0.0167 -- # of Clones 20
# Time  0.836 Myr-- Fraction Done 0.0167 -- # of Clones 20
# Time  0.837 Myr-- Fraction Done 0.0167 -- # of Clones 20
# Time  0.838 Myr-- Fraction Done 0.0168 -- # of Clones 20
# Time  0.839 Myr-- Fraction Done 0.0168 -- # of Clones 20
# Time  0.840 Myr-- Fraction Done 0.0168 -- # of Clones 20
# Time  0.841 Myr-- Fraction Done 0.0168 -- # of Clones 20
# ...
# Time  3.482 Myr-- Fraction Done 0.0696 -- # of Clones 20
# Time  3.483 Myr-- Fraction Done 0.0697 -- # of Clones 20
# Time  3.484 Myr-- Fraction Done 0.0697 -- # of Clones 20
# Time  3.485 Myr-- Fraction Done 0.0697 -- # of Clones 20
# Time  3.486 Myr-- Fraction Done 0.0697 -- # of Clones 20
# Time  3.487 Myr-- Fraction Done 0.0697 -- # of Clones 20
# Time  3.488 Myr-- Fraction Done 0.0698 -- # of Clones 20
# Time  3.489 Myr-- Fraction Done 0.0698 -- # of Clones 20
# Time  3.490 Myr-- Fraction Done 0.0698 -- # of Clones 20
# Time  3.491 Myr-- Fraction Done 0.0698 -- # of Clones 20
# Time  3.492 Myr-- Fraction Done 0.0698 -- # of Clones 20
# Time  3.493 Myr-- Fraction Done 0.0699 -- # of Clones 20
# Time  3.494 Myr-- Fraction Done 0.0699 -- # of Clones 20
# Time  3.495 Myr-- Fraction Done 0.0699 -- # of Clones 20
# Time  3.496 Myr-- Fraction Done 0.0699 -- # of Clones 20
# Time  3.497 Myr-- Fraction Done 0.0699 -- # of Clones 20
# Time  3.498 Myr-- Fraction Done 0.0700 -- # of Clones 20
# Time  3.499 Myr-- Fraction Done 0.0700 -- # of Clones 20
# Time  3.500 Myr-- Fraction Done 0.0700 -- # of Clones 20
# Time  3.501 Myr-- Fraction Done 0.0700 -- # of Clones 20
# Time  3.502 Myr-- Fraction Done 0.0700 -- # of Clones 20
# Time  3.503 Myr-- Fraction Done 0.0701 -- # of Clones 20
# Time  3.504 Myr-- Fraction Done 0.0701 -- # of Clones 20
# Time  3.505 Myr-- Fraction Done 0.0701 -- # of Clones 20
# Time  3.506 Myr-- Fraction Done 0.0701 -- # of Clones 20
# Time  3.507 Myr-- Fraction Done 0.0701 -- # of Clones 20
# Time  3.508 Myr-- Fraction Done 0.0702 -- # of Clones 20
# Time  3.509 Myr-- Fraction Done 0.0702 -- # of Clones 20
# Time  3.510 Myr-- Fraction Done 0.0702 -- # of Clones 20
# Time  3.511 Myr-- Fraction Done 0.0702 -- # of Clones 20
# Time  3.512 Myr-- Fraction Done 0.0702 -- # of Clones 20
# Time  3.513 Myr-- Fraction Done 0.0703 -- # of Clones 20
# Time  3.514 Myr-- Fraction Done 0.0703 -- # of Clones 20
# Time  3.515 Myr-- Fraction Done 0.0703 -- # of Clones 20
# Time  3.516 Myr-- Fraction Done 0.0703 -- # of Clones 20
# Time  3.517 Myr-- Fraction Done 0.0703 -- # of Clones 20
# Time  3.518 Myr-- Fraction Done 0.0704 -- # of Clones 20
# Time  3.519 Myr-- Fraction Done 0.0704 -- # of Clones 20
# Time  3.520 Myr-- Fraction Done 0.0704 -- # of Clones 20
# Time  3.521 Myr-- Fraction Done 0.0704 -- # of Clones 20
# Time  3.522 Myr-- Fraction Done 0.0704 -- # of Clones 20
# Time  3.523 Myr-- Fraction Done 0.0705 -- # of Clones 20
# Time  3.524 Myr-- Fraction Done 0.0705 -- # of Clones 20
# Time  3.525 Myr-- Fraction Done 0.0705 -- # of Clones 20
# Time  3.526 Myr-- Fraction Done 0.0705 -- # of Clones 20
# Time  3.527 Myr-- Fraction Done 0.0705 -- # of Clones 20
# Time  3.528 Myr-- Fraction Done 0.0706 -- # of Clones 20
# Time  3.529 Myr-- Fraction Done 0.0706 -- # of Clones 20
# Time  3.530 Myr-- Fraction Done 0.0706 -- # of Clones 20
# Time  3.531 Myr-- Fraction Done 0.0706 -- # of Clones 20
# Time  3.532 Myr-- Fraction Done 0.0706 -- # of Clones 20
# Time  3.533 Myr-- Fraction Done 0.0707 -- # of Clones 20
# Time  3.534 Myr-- Fraction Done 0.0707 -- # of Clones 20
# Time  3.535 Myr-- Fraction Done 0.0707 -- # of Clones 20
# Time  3.536 Myr-- Fraction Done 0.0707 -- # of Clones 20
# Time  3.537 Myr-- Fraction Done 0.0707 -- # of Clones 20
# Time  3.538 Myr-- Fraction Done 0.0708 -- # of Clones 20
# Time  3.539 Myr-- Fraction Done 0.0708 -- # of Clones 20
# Time  3.540 Myr-- Fraction Done 0.0708 -- # of Clones 20
# Time  3.541 Myr-- Fraction Done 0.0708 -- # of Clones 20
# Time  3.542 Myr-- Fraction Done 0.0708 -- # of Clones 20
# Time  3.543 Myr-- Fraction Done 0.0709 -- # of Clones 20
# Time  3.544 Myr-- Fraction Done 0.0709 -- # of Clones 20
# Time  3.545 Myr-- Fraction Done 0.0709 -- # of Clones 20
# Time  3.546 Myr-- Fraction Done 0.0709 -- # of Clones 20
# Time  3.547 Myr-- Fraction Done 0.0709 -- # of Clones 20
# Time  3.548 Myr-- Fraction Done 0.0710 -- # of Clones 20
# Time  3.549 Myr-- Fraction Done 0.0710 -- # of Clones 20
# Time  3.550 Myr-- Fraction Done 0.0710 -- # of Clones 20
# Time  3.551 Myr-- Fraction Done 0.0710 -- # of Clones 20
# Time  3.552 Myr-- Fraction Done 0.0710 -- # of Clones 20
# Time  3.553 Myr-- Fraction Done 0.0711 -- # of Clones 20
# Time  3.554 Myr-- Fraction Done 0.0711 -- # of Clones 20
# Time  3.555 Myr-- Fraction Done 0.0711 -- # of Clones 20
# Time  3.556 Myr-- Fraction Done 0.0711 -- # of Clones 20
# Time  3.557 Myr-- Fraction Done 0.0711 -- # of Clones 20
# Time  3.558 Myr-- Fraction Done 0.0712 -- # of Clones 20
# Time  3.559 Myr-- Fraction Done 0.0712 -- # of Clones 20
# Time  3.560 Myr-- Fraction Done 0.0712 -- # of Clones 20
# Time  3.561 Myr-- Fraction Done 0.0712 -- # of Clones 20
# Time  3.562 Myr-- Fraction Done 0.0712 -- # of Clones 20
# Time  3.563 Myr-- Fraction Done 0.0713 -- # of Clones 20
# Time  3.564 Myr-- Fraction Done 0.0713 -- # of Clones 20
# Time  3.565 Myr-- Fraction Done 0.0713 -- # of Clones 20
# Time  3.566 Myr-- Fraction Done 0.0713 -- # of Clones 20
# Time  3.567 Myr-- Fraction Done 0.0713 -- # of Clones 20
# Time  3.568 Myr-- Fraction Done 0.0714 -- # of Clones 20
# Time  3.569 Myr-- Fraction Done 0.0714 -- # of Clones 20
# Time  3.570 Myr-- Fraction Done 0.0714 -- # of Clones 20
# Time  3.571 Myr-- Fraction Done 0.0714 -- # of Clones 20
# Time  3.572 Myr-- Fraction Done 0.0714 -- # of Clones 20
# Time  3.573 Myr-- Fraction Done 0.0715 -- # of Clones 20
# Time  3.574 Myr-- Fraction Done 0.0715 -- # of Clones 20
# Time  3.575 Myr-- Fraction Done 0.0715 -- # of Clones 20
# Time  3.576 Myr-- Fraction Done 0.0715 -- # of Clones 20
# Time  3.577 Myr-- Fraction Done 0.0715 -- # of Clones 20
# Time  3.578 Myr-- Fraction Done 0.0716 -- # of Clones 20
# Time  3.579 Myr-- Fraction Done 0.0716 -- # of Clones 20
# Time  3.580 Myr-- Fraction Done 0.0716 -- # of Clones 20
# Time  3.581 Myr-- Fraction Done 0.0716 -- # of Clones 20
# Time  3.582 Myr-- Fraction Done 0.0716 -- # of Clones 20
# Time  3.583 Myr-- Fraction Done 0.0717 -- # of Clones 20
# Time  3.584 Myr-- Fraction Done 0.0717 -- # of Clones 20
# Time  3.585 Myr-- Fraction Done 0.0717 -- # of Clones 20
# Time  3.586 Myr-- Fraction Done 0.0717 -- # of Clones 20
# Time  3.587 Myr-- Fraction Done 0.0717 -- # of Clones 20
# Time  3.588 Myr-- Fraction Done 0.0718 -- # of Clones 20
# Time  3.589 Myr-- Fraction Done 0.0718 -- # of Clones 20
# Time  3.590 Myr-- Fraction Done 0.0718 -- # of Clones 20
# Time  3.591 Myr-- Fraction Done 0.0718 -- # of Clones 20
# Time  3.592 Myr-- Fraction Done 0.0718 -- # of Clones 20
# Time  3.593 Myr-- Fraction Done 0.0719 -- # of Clones 20
# Time  3.594 Myr-- Fraction Done 0.0719 -- # of Clones 20
# Time  3.595 Myr-- Fraction Done 0.0719 -- # of Clones 20
# Time  3.596 Myr-- Fraction Done 0.0719 -- # of Clones 20
# Time  3.597 Myr-- Fraction Done 0.0719 -- # of Clones 20
# Time  3.598 Myr-- Fraction Done 0.0720 -- # of Clones 20
# Time  3.599 Myr-- Fraction Done 0.0720 -- # of Clones 20
# Time  3.600 Myr-- Fraction Done 0.0720 -- # of Clones 20
# Time  3.601 Myr-- Fraction Done 0.0720 -- # of Clones 20
# Time  3.602 Myr-- Fraction Done 0.0720 -- # of Clones 20
# Time  3.603 Myr-- Fraction Done 0.0721 -- # of Clones 20
# Time  3.604 Myr-- Fraction Done 0.0721 -- # of Clones 20
# Time  3.605 Myr-- Fraction Done 0.0721 -- # of Clones 20
# Time  3.606 Myr-- Fraction Done 0.0721 -- # of Clones 20
# Time  3.607 Myr-- Fraction Done 0.0721 -- # of Clones 20
# Time  3.608 Myr-- Fraction Done 0.0722 -- # of Clones 20
# Time  3.609 Myr-- Fraction Done 0.0722 -- # of Clones 20
# Time  3.610 Myr-- Fraction Done 0.0722 -- # of Clones 20
# Time  3.611 Myr-- Fraction Done 0.0722 -- # of Clones 20
# Time  3.612 Myr-- Fraction Done 0.0722 -- # of Clones 20
# Time  3.613 Myr-- Fraction Done 0.0723 -- # of Clones 20
# Time  3.614 Myr-- Fraction Done 0.0723 -- # of Clones 20
# Time  3.615 Myr-- Fraction Done 0.0723 -- # of Clones 20
# Time  3.616 Myr-- Fraction Done 0.0723 -- # of Clones 20
# Time  3.617 Myr-- Fraction Done 0.0723 -- # of Clones 20
# Time  3.618 Myr-- Fraction Done 0.0724 -- # of Clones 20
# Time  3.619 Myr-- Fraction Done 0.0724 -- # of Clones 20
# Time  3.620 Myr-- Fraction Done 0.0724 -- # of Clones 20
# Time  3.621 Myr-- Fraction Done 0.0724 -- # of Clones 20
# Time  3.622 Myr-- Fraction Done 0.0724 -- # of Clones 20
# Time  3.623 Myr-- Fraction Done 0.0725 -- # of Clones 20
# Time  3.624 Myr-- Fraction Done 0.0725 -- # of Clones 20
# Time  3.625 Myr-- Fraction Done 0.0725 -- # of Clones 20
# Time  3.626 Myr-- Fraction Done 0.0725 -- # of Clones 20
# Time  3.627 Myr-- Fraction Done 0.0725 -- # of Clones 20
# Time  3.628 Myr-- Fraction Done 0.0726 -- # of Clones 20
# Time  3.629 Myr-- Fraction Done 0.0726 -- # of Clones 20
# Time  3.630 Myr-- Fraction Done 0.0726 -- # of Clones 20
# Time  3.631 Myr-- Fraction Done 0.0726 -- # of Clones 20
# Time  3.632 Myr-- Fraction Done 0.0726 -- # of Clones 20
# Time  3.633 Myr-- Fraction Done 0.0727 -- # of Clones 20
# Time  3.634 Myr-- Fraction Done 0.0727 -- # of Clones 20
# Time  3.635 Myr-- Fraction Done 0.0727 -- # of Clones 20
# Time  3.636 Myr-- Fraction Done 0.0727 -- # of Clones 20
# Time  3.637 Myr-- Fraction Done 0.0727 -- # of Clones 20
# Time  3.638 Myr-- Fraction Done 0.0728 -- # of Clones 20
# Time  3.639 Myr-- Fraction Done 0.0728 -- # of Clones 20
# Time  3.640 Myr-- Fraction Done 0.0728 -- # of Clones 20
# Time  3.641 Myr-- Fraction Done 0.0728 -- # of Clones 20
# Time  3.642 Myr-- Fraction Done 0.0728 -- # of Clones 20
# Time  3.643 Myr-- Fraction Done 0.0729 -- # of Clones 20
# Time  3.644 Myr-- Fraction Done 0.0729 -- # of Clones 20
# Time  3.645 Myr-- Fraction Done 0.0729 -- # of Clones 20
# Time  3.646 Myr-- Fraction Done 0.0729 -- # of Clones 20
# Time  3.647 Myr-- Fraction Done 0.0729 -- # of Clones 20
# Time  3.648 Myr-- Fraction Done 0.0730 -- # of Clones 20
# Time  3.649 Myr-- Fraction Done 0.0730 -- # of Clones 20
# Time  3.650 Myr-- Fraction Done 0.0730 -- # of Clones 20
# Time  3.651 Myr-- Fraction Done 0.0730 -- # of Clones 20
# Time  3.652 Myr-- Fraction Done 0.0730 -- # of Clones 20
# Time  3.653 Myr-- Fraction Done 0.0731 -- # of Clones 20
# Time  3.654 Myr-- Fraction Done 0.0731 -- # of Clones 20
# Time  3.655 Myr-- Fraction Done 0.0731 -- # of Clones 20
# Time  3.656 Myr-- Fraction Done 0.0731 -- # of Clones 20
# Time  3.657 Myr-- Fraction Done 0.0731 -- # of Clones 20
# Time  3.658 Myr-- Fraction Done 0.0732 -- # of Clones 20
# Time  3.659 Myr-- Fraction Done 0.0732 -- # of Clones 20
# Time  3.660 Myr-- Fraction Done 0.0732 -- # of Clones 20
# Time  3.661 Myr-- Fraction Done 0.0732 -- # of Clones 20
# Time  3.662 Myr-- Fraction Done 0.0732 -- # of Clones 20
# Time  3.663 Myr-- Fraction Done 0.0733 -- # of Clones 20
# Time  3.664 Myr-- Fraction Done 0.0733 -- # of Clones 20
# Time  3.665 Myr-- Fraction Done 0.0733 -- # of Clones 20
# Time  3.666 Myr-- Fraction Done 0.0733 -- # of Clones 20
# Time  3.667 Myr-- Fraction Done 0.0733 -- # of Clones 20
# Time  3.668 Myr-- Fraction Done 0.0734 -- # of Clones 20
# Time  3.669 Myr-- Fraction Done 0.0734 -- # of Clones 20
# Time  3.670 Myr-- Fraction Done 0.0734 -- # of Clones 20
# Time  3.671 Myr-- Fraction Done 0.0734 -- # of Clones 20
# Time  3.672 Myr-- Fraction Done 0.0734 -- # of Clones 20
# Time  3.673 Myr-- Fraction Done 0.0735 -- # of Clones 20
# Time  3.674 Myr-- Fraction Done 0.0735 -- # of Clones 20
# Time  3.675 Myr-- Fraction Done 0.0735 -- # of Clones 20
# Time  3.676 Myr-- Fraction Done 0.0735 -- # of Clones 20
# Time  3.677 Myr-- Fraction Done 0.0735 -- # of Clones 20
# Time  3.678 Myr-- Fraction Done 0.0736 -- # of Clones 20
# Time  3.679 Myr-- Fraction Done 0.0736 -- # of Clones 20
# Time  3.680 Myr-- Fraction Done 0.0736 -- # of Clones 20
# Time  3.681 Myr-- Fraction Done 0.0736 -- # of Clones 20
# Time  3.682 Myr-- Fraction Done 0.0736 -- # of Clones 20
# Time  3.683 Myr-- Fraction Done 0.0737 -- # of Clones 20
# Time  3.684 Myr-- Fraction Done 0.0737 -- # of Clones 20
# Time  3.685 Myr-- Fraction Done 0.0737 -- # of Clones 20
# Time  3.686 Myr-- Fraction Done 0.0737 -- # of Clones 20
# Time  3.687 Myr-- Fraction Done 0.0737 -- # of Clones 20
# Time  3.688 Myr-- Fraction Done 0.0738 -- # of Clones 20
# Time  3.689 Myr-- Fraction Done 0.0738 -- # of Clones 20
# Time  3.690 Myr-- Fraction Done 0.0738 -- # of Clones 20
# Time  3.691 Myr-- Fraction Done 0.0738 -- # of Clones 20
# Time  3.692 Myr-- Fraction Done 0.0738 -- # of Clones 20
# Time  3.693 Myr-- Fraction Done 0.0739 -- # of Clones 20
# Time  3.694 Myr-- Fraction Done 0.0739 -- # of Clones 20
# Time  3.695 Myr-- Fraction Done 0.0739 -- # of Clones 20
# Time  3.696 Myr-- Fraction Done 0.0739 -- # of Clones 20
# Time  3.697 Myr-- Fraction Done 0.0739 -- # of Clones 20
# Time  3.698 Myr-- Fraction Done 0.0740 -- # of Clones 20
# Time  3.699 Myr-- Fraction Done 0.0740 -- # of Clones 20
# Time  3.700 Myr-- Fraction Done 0.0740 -- # of Clones 20
# Time  3.701 Myr-- Fraction Done 0.0740 -- # of Clones 20
# Time  3.702 Myr-- Fraction Done 0.0740 -- # of Clones 20
# Time  3.703 Myr-- Fraction Done 0.0741 -- # of Clones 20
# Time  3.704 Myr-- Fraction Done 0.0741 -- # of Clones 20
# Time  3.705 Myr-- Fraction Done 0.0741 -- # of Clones 20
# Time  3.706 Myr-- Fraction Done 0.0741 -- # of Clones 20
# Time  3.707 Myr-- Fraction Done 0.0741 -- # of Clones 20
# Time  3.708 Myr-- Fraction Done 0.0742 -- # of Clones 20
# Time  3.709 Myr-- Fraction Done 0.0742 -- # of Clones 20
# Time  3.710 Myr-- Fraction Done 0.0742 -- # of Clones 20
# Time  3.711 Myr-- Fraction Done 0.0742 -- # of Clones 20
# Time  3.712 Myr-- Fraction Done 0.0742 -- # of Clones 20
# Time  3.713 Myr-- Fraction Done 0.0743 -- # of Clones 20
# Time  3.714 Myr-- Fraction Done 0.0743 -- # of Clones 20
# Time  3.715 Myr-- Fraction Done 0.0743 -- # of Clones 20
# Time  3.716 Myr-- Fraction Done 0.0743 -- # of Clones 20
# Time  3.717 Myr-- Fraction Done 0.0743 -- # of Clones 20
# Time  3.718 Myr-- Fraction Done 0.0744 -- # of Clones 20
# Time  3.719 Myr-- Fraction Done 0.0744 -- # of Clones 20
# Time  3.720 Myr-- Fraction Done 0.0744 -- # of Clones 20
# Time  3.721 Myr-- Fraction Done 0.0744 -- # of Clones 20
# Time  3.722 Myr-- Fraction Done 0.0744 -- # of Clones 20
# Time  3.723 Myr-- Fraction Done 0.0745 -- # of Clones 20
# Time  3.724 Myr-- Fraction Done 0.0745 -- # of Clones 20
# Time  3.725 Myr-- Fraction Done 0.0745 -- # of Clones 20
# Time  3.726 Myr-- Fraction Done 0.0745 -- # of Clones 20
# Time  3.727 Myr-- Fraction Done 0.0745 -- # of Clones 20
# Time  3.728 Myr-- Fraction Done 0.0746 -- # of Clones 20
# Time  3.729 Myr-- Fraction Done 0.0746 -- # of Clones 20
# Time  3.730 Myr-- Fraction Done 0.0746 -- # of Clones 20
# Time  3.731 Myr-- Fraction Done 0.0746 -- # of Clones 20
# Time  3.732 Myr-- Fraction Done 0.0746 -- # of Clones 20
# Time  3.733 Myr-- Fraction Done 0.0747 -- # of Clones 20
# Time  3.734 Myr-- Fraction Done 0.0747 -- # of Clones 20
# Time  3.735 Myr-- Fraction Done 0.0747 -- # of Clones 20
# Time  3.736 Myr-- Fraction Done 0.0747 -- # of Clones 20
# Time  3.737 Myr-- Fraction Done 0.0747 -- # of Clones 20
# Time  3.738 Myr-- Fraction Done 0.0748 -- # of Clones 20
# Time  3.739 Myr-- Fraction Done 0.0748 -- # of Clones 20
# Time  3.740 Myr-- Fraction Done 0.0748 -- # of Clones 20
# Time  3.741 Myr-- Fraction Done 0.0748 -- # of Clones 20
# Time  3.742 Myr-- Fraction Done 0.0748 -- # of Clones 20
# Time  3.743 Myr-- Fraction Done 0.0749 -- # of Clones 20
# Time  3.744 Myr-- Fraction Done 0.0749 -- # of Clones 20
# Time  3.745 Myr-- Fraction Done 0.0749 -- # of Clones 20
# Time  3.746 Myr-- Fraction Done 0.0749 -- # of Clones 20
# Time  3.747 Myr-- Fraction Done 0.0749 -- # of Clones 20
# Time  3.748 Myr-- Fraction Done 0.0750 -- # of Clones 20
# Time  3.749 Myr-- Fraction Done 0.0750 -- # of Clones 20
# Time  3.750 Myr-- Fraction Done 0.0750 -- # of Clones 20
# Time  3.751 Myr-- Fraction Done 0.0750 -- # of Clones 20
# Time  3.752 Myr-- Fraction Done 0.0750 -- # of Clones 20
# Time  3.753 Myr-- Fraction Done 0.0751 -- # of Clones 20
# Time  3.754 Myr-- Fraction Done 0.0751 -- # of Clones 20
# Time  3.755 Myr-- Fraction Done 0.0751 -- # of Clones 20
# Time  3.756 Myr-- Fraction Done 0.0751 -- # of Clones 20
# Time  3.757 Myr-- Fraction Done 0.0751 -- # of Clones 20
# Time  3.758 Myr-- Fraction Done 0.0752 -- # of Clones 20
# Time  3.759 Myr-- Fraction Done 0.0752 -- # of Clones 20
# Time  3.760 Myr-- Fraction Done 0.0752 -- # of Clones 20
# Time  3.761 Myr-- Fraction Done 0.0752 -- # of Clones 20
